# %% [markdown]
# # Assignment Netwerkanalyse

# %% [markdown]
# ## Notebook made by
#
#
# |Naam|Studentnummer|
# |-|-|
# |Friso| secret |
# |Rico| secret |
# |Sander| secret |
# |Sam| secret |
#
# ## Peerreview
#
# * Vul onderstaande dict/tabel in en run de cel. Klopt het? Zijn jullie het er allemaal mee eens?
#     * Verander `1,2,3,4` door jullie studentnummers
#     * `1: {1:.2,2:.3,3:.3,4:.2}` betekent dat student 1 zijn punt zo over de 4 studenten verdeelt
#     * Let op, per student moeten de punten optellen tot 1!
#     * De gegeven punten staan in de tabel op de rijen, de ontvangen punten in de kolommen.
#     * met `cijfer_per_student` kan je bepalen welk cijfer ieder krijgt bij een gegeven groepscijfer.

# %% [markdown]
# ## Toelichting
#
# * De meeste opgaven worden automatisch nagekeken. Bij vrijwel alle opdrachten staan er een paar tests onder de opdracht, dit is voornamelijk om te zorgen dat je de juiste type output geeft. Dit zijn dus *NIET* alle tests, die komen er bij het graden nog bij.
# * Elke vraag is 1 punt waard, tenzij anders aangegeven. Soms is die punt onderverdeeld in deelpunten, maar niet altijd.
#
# ## Voor het inleveren!
#
# * Pas niet de cellen aan, vooral niet die je niet kunt editen. Dit levert problemen op bij nakijken. Twijfel je of je per ongeluk iets hebt gewijzigd, kopieer dan bij inleveren je antwoorden naar een nieuw bestand, zodat het niet fout kan gaan.
#
# * Zorg dat de code goed runt van boven naar beneden, verifieer dat door boven in Kernel -> Restart & Run All uit te voeren
#
# ## Na het inleveren!
#
# * Het gebeurt erg vaak dat mensen een "leeg bestand" inleveren. Vaak een andere versie van de opgave die nog ergens op je computer rondslingerde. Zonde van al je werk toch!
# * Dus, lever **minstens een half uur voor tijd in**. Download dan wat je hebt ingeleverd op Canvas. Geef het een andere naam om verwarring te voorkomen. En draai alle cellen, en bekijk het. Geen syntax fouten? Alle vragen gemaakt? Dan zit het vast wel goed, en hoef je niet in de zenuwen te zitten.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Assignment-Netwerkanalyse" data-toc-modified-id="Assignment-Netwerkanalyse-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Assignment Netwerkanalyse</a></span><ul class="toc-item"><li><span><a href="#Notebook-made-by" data-toc-modified-id="Notebook-made-by-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Notebook made by</a></span></li><li><span><a href="#Peerreview" data-toc-modified-id="Peerreview-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Peerreview</a></span></li><li><span><a href="#Toelichting" data-toc-modified-id="Toelichting-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Toelichting</a></span></li><li><span><a href="#Voor-het-inleveren!" data-toc-modified-id="Voor-het-inleveren!-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Voor het inleveren!</a></span></li><li><span><a href="#Na-het-inleveren!" data-toc-modified-id="Na-het-inleveren!-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Na het inleveren!</a></span></li></ul></li><li><span><a href="#Prop-logic-1-(10pt)" data-toc-modified-id="Prop-logic-1-(10pt)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Prop logic 1 (10pt)</a></span><ul class="toc-item"><li><span><a href="#Jullie-opdracht" data-toc-modified-id="Jullie-opdracht-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Jullie opdracht</a></span><ul class="toc-item"><li><span><a href="#Beoordeling" data-toc-modified-id="Beoordeling-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Beoordeling</a></span></li></ul></li></ul></li><li><span><a href="#Prop-logic-2-(0pt)" data-toc-modified-id="Prop-logic-2-(0pt)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Prop logic 2 (0pt)</a></span></li></ul></div>

# %% [markdown]
# # Prop logic 1 (10pt)
#
# Met 2 variabelen `p` en `q` kan je natuurlijk oneindig veel verschillende formules maken.
# **Laat dat zien met wat voorbeelden. Het geeft niet als ze flauw zijn.**
# Maar je kan maar 16 verschillende waarheidstafels maken. Hieronder staat er eentje. Omdat je vier vakjes met T en F (2 waarden) kunt invullen, zijn er dus $2^4$ verschillende tafels te maken. **Voor welke formule is deze tafel?**  (helemaal onderaan staat het antwoord)
#
#
# |  | P True  | P False|
# | --- | --- | --- |
# | **Q True** | T | F |
# | **Q False** | T | T |
#
# ## Jullie opdracht
#
# Maak een prachtig uitziend, helder geordend overzicht van deze 16 tabellen, en geef bij elke tabel de formule die exact de betekenis heeft gegeven door die tabel. **Je formule mag alleen $p,q,\neg,\rightarrow,\leftrightarrow$ bevatten.**
#
# Je mag het in Markdown en LaTeX doen, maar ook met de hand tekenen, en schilderen.  Maak je iets met de hand, maak dan een goede foto, zet die ergens op het web, en link ernaar in je Markdown antwoord. Als je naar de code van deze cel kijkt, zie je hoe je in MarkDown een link naar een plaatje maakt.
#
# ![A tableaux proof for the propositional formula ((a ∨ ¬b) ∧ b) → a.](https://upload.wikimedia.org/wikipedia/commons/thumb/2/21/Prop-tableau-4.svg/300px-Prop-tableau-4.svg.png)
#
# ### Beoordeling
#
# * Het is super eenvoudig om in Python te checken of je antwoord correct is.
# * Een antwoord met dus ook maar 1 fout erin is dan dus ook onvoldoende.
# * De hoogte van je voldoende wordt bepaald door de schoonheid en overzichtelijkheid van je werk, en de elegantie van de gekozen formules.
#
#
#
# $q\rightarrow p$

# %%
# %%html
# <style>
#     /* Jupyter */
#     .rendered_html table,
#     /* Jupyter Lab*/
#     div[data-mime-type="text-markdown"] table {
#         margin-left: 0;
#         flex-direction: row;
#     }
# </style>
# Out:
# <style>
#     /* Jupyter */
#     .rendered_html table,
#     /* Jupyter Lab*/
#     div[data-mime-type="text-markdown"] table {
#         margin-left: 0;
#         flex-direction: row;
#     }
# </style>

# %% [markdown]
# 1:
#
# |  p  |  q  |p $\rightarrow$ p|
#                     |-|-|:-:|
#                     |  T  |  T  |  T  |
#                     |  T  |  F  |  T  |
#                     |  F  |  T  |  T  |
#                     |  F  |  F  |  T  |
#
# 2:
#
# |  p  |  q  |($\neg$ p) $\rightarrow$ q|
#                     |-|-|:-:|
#                     |  T  |  T  |  T  |
#                     |  T  |  F  |  T  |
#                     |  F  |  T  |  T  |
#                     |  F  |  F  |  F  |
#
# 3:
#
# |  p  |  q  | q $\rightarrow$ p|
#                     |-|-|:-:|
#                     |  T  |  T  |  T  |
#                     |  T  |  F  |  T  |
#                     |  F  |  T  |  F  |
#                     |  F  |  F  |  T  |
#
# 4:
#
# |  p  |  q  |p|
#                     |-|-|:-:|
#                     |  T  |  T  |  T  |
#                     |  T  |  F  |  T  |
#                     |  F  |  T  |  F  |
#                     |  F  |  F  |  F  |
#
# 5:
#
# |  p  |  q  |p $\rightarrow$ q|
#                     |-|-|:-:|
#                     |  T  |  T  |  T  |
#                     |  T  |  F  |  F  |
#                     |  F  |  T  |  T  |
#                     |  F  |  F  |  T  |
#
# 6:
#
# |  p  |  q  |q|
#                     |-|-|:-:|
#                     |  T  |  T  |  T  |
#                     |  T  |  F  |  F  |
#                     |  F  |  T  |  T  |
#                     |  F  |  F  |  F  |
#
# 7:
#
# |  p  |  q  |p $\leftrightarrow$ q|
#                     |-|-|:-:|
#                     |  T  |  T  |  T  |
#                     |  T  |  F  |  F  |
#                     |  F  |  T  |  F  |
#                     |  F  |  F  |  T  |
#
# 8:
#
# |  p  |  q  |$\neg$ (p $\rightarrow$ ($\neg$ q)|
#                     |-|-|:-:|
#                     |  T  |  T  |  T  |
#                     |  T  |  F  |  F  |
#                     |  F  |  T  |  F  |
#                     |  F  |  F  |  F  |
#
# 9:
#
# |  p  |  q  |p $\rightarrow$ ($\neg$ q)|
#                     |-|-|:-:|
#                     |  T  |  T  |  F  |
#                     |  T  |  F  |  T  |
#                     |  F  |  T  |  T  |
#                     |  F  |  F  |  T  |
#
# 10:
#
# |  p  |  q  |$\neg$(p $\leftrightarrow$ q)|
#                     |-|-|:-:|
#                     |  T  |  T  |  F  |
#                     |  T  |  F  |  T  |
#                     |  F  |  T  |  T  |
#                     |  F  |  F  |  F  |
#
# 11:
#
# |  p  |  q  |$\neg$ q|
#                     |-|-|:-:|
#                     |  T  |  T  |  F  |
#                     |  T  |  F  |  T  |
#                     |  F  |  T  |  F  |
#                     |  F  |  F  |  T  |
#
# 12:
#
# |  p  |  q  |$\neg$ (p $\rightarrow$ q)|
#                     |-|-|:-:|
#                     |  T  |  T  |  F  |
#                     |  T  |  F  |  T  |
#                     |  F  |  T  |  F  |
#                     |  F  |  F  |  F  |
#
# 13:
#
# |  p  |  q  |$\neg$ p|
#                     |-|-|:-:|
#                     |  T  |  T  |  F  |
#                     |  T  |  F  |  F  |
#                     |  F  |  T  |  T  |
#                     |  F  |  F  |  T  |
#
# 14:
#
# |  p  |  q  |$\neg$ (q $\rightarrow$ p)|
#                     |-|-|:-:|
#                     |  T  |  T  |  F  |
#                     |  T  |  F  |  F  |
#                     |  F  |  T  |  T  |
#                     |  F  |  F  |  F  |
#
# 15:
#
# |  p  |  q  |$\neg$ (($\neg$p) $\rightarrow$ q)|
#                     |-|-|:-:|
#                     |  T  |  T  |  F  |
#                     |  T  |  F  |  F  |
#                     |  F  |  T  |  F  |
#                     |  F  |  F  |  T  |
#
# 16:
#
# |  p  |  q  |$\neg$(p $\rightarrow$ p)|
#                     |-|-|:-:|
#                     |  T  |  T  |  F  |
#                     |  T  |  F  |  F  |
#                     |  F  |  T  |  F  |
#                     |  F  |  F  |  F  |

# %% [markdown]
# # Prop logic 2 (0pt)
#
# Maak  opgaven 16.1-16.5 in <https://www.stat.berkeley.edu/~stark/SticiGui/Text/logic.htm>.
#
# De antwoorden staan erbij, behalve bij 16.1, maar die zijn makkelijk met behulp van de waarheidstafels voor de connectieven te checken.
#
# Een goede manier is om alle opgaven zelf te maken, en ze dan in je groepje te bespreken en te vergelijken. Zo moet je wel tot de juiste antwoorden komen. Geef niet alleen het antwoord maar ook een heldere uitleg waarom je dat antwoord geeft.
#
# Bijvoorbeeld: *4 is prima and $-1\times -1= -1$* is niet waar want $-1\times -1= -1$ is niet waar en een conjunctie (*and*) is onwaar als 1 van de conjuncten (de delen) onwaar is.
#
# **Tip** als je de pagina ververst krijg je soms weer andere opdrachten.
#
# Copieer je antwoorden in de cel hieronder.
#
# **Hint** Denk nou niet, he 0 punten, dus dat is zinloos om te doen. Nee, want op het tentamen stikt het van dit soort puzzeltjes. Het is echt oefenen wil je daar handig en foutloos in worden.

# %% [markdown]
# ### 16.1
# (Dit zijn een aantal propositions van 16.1, ik had geen zin om ze allemaal op te schrijven)
# - **Homer Simpson is President of the U.S.A.** is niet waar, want Homer Simpson is niet president van amerika
# - **4 is prime | the moon is made of cheese** is niet waar, want 4 is geen priemgetal en de maan bestaat niet uit kaas, een logical disjunction is niet waar als beide propositions niet waar zijn
# - **4 is prime $\rightarrow$ the moon is made of cheese** is waar, want deze conditional proposition is logically equivalent aan **4 is not prime | the moon is made of cheese**, een logical disjunction is waar als één van de propositions waar is en 4 is niet een priemgetal. Die proposition is dus waar.
# - **$-1\times -1= -1$ & $2 + 2 = 4$** is waar, want beide propositions zijn waar en een conjunction is waar als beide propositions waar zijn.
# - **3 is an odd integer | Homer Simpson is President of the U.S.A.** is waar, dit is weer een disjunction en het klopt dat 3 een oneven integer is, dus is deze disjunction waar.
# - **4 is prime & 3 is an odd integer** is niet waar, weer een conjunction waarvan één proposition niet waar is (4 is geen priemgetal), dus deze conjunction is niet waar.
#
# ### 16.2
#
# |q|p|($\neg$p) $\wedge$ q|
# |-|-|-|
# |T|T|F|
# |T|F|F|
# |F|T|T|
# |F|F|F|
#
# ($\neg$p) $\wedge$ q is een conjunction, dus deze proposition is alleen waar als beide (sub)propositions waar zijn, !p is waar als p niet waar is en q is waar als q waar is.
#
# ### 16.3
#
# |q|p|(((($\neg$ p) $\rightarrow$ ($\neg$ q)) $\vee$ (($\neg$ q) $\wedge$ p)) $\wedge$ ($\neg$(($\neg$(q $\rightarrow$ q)) $\wedge$ ($\neg$($\neg$ q))))) $\rightarrow$ (($\neg$(q $\rightarrow$ q)) $\wedge$ ($\neg$($\neg$ q)))|
# |-|-|-|
# |T|T|F|
# |T|F|F|
# |F|T|T|
# |F|F|F|
#
# (((($\neg$ p) $\rightarrow$ ($\neg$ q)) $\vee$ (($\neg$ q) $\wedge$ p)) $\wedge$ ($\neg$(($\neg$(q $\rightarrow$ q)) $\wedge$ ($\neg$($\neg$ q))))) $\rightarrow$ (($\neg$(q $\rightarrow$ q)) $\wedge$ ($\neg$($\neg$ q))) is natuurlijk heel groot, maar kan makkelijk in stukken gebroken worden naar bijvoorbeeld:
#
# f = $\neg$(x $\wedge$ y) $\vee$ z
#
# - x = ((p $\vee$ ($\neg$q)) $\vee$ (p $\wedge$ ($\neg$q)))
# - y = $\neg$(($\neg$(($\neg$q) $\vee$ q)) $\wedge$ q)
# - z = (($\neg$(($\neg$q) $\vee$ q)) $\wedge$ q)
#
# y is altijd T, want ($\neg$(($\neg$q) $\vee$ q)) is altijd F, de conjunction die volgt is dus altijd F, maar die wordt T door de buitenste $\neg$.
#
# z is altijd F, om dezelfde reden als y, maar dan zonder buitenste $\neg$.
#
# nu we dit weten kan f deels worden ingevuld:
#
# f = $\neg$(x $\wedge$ T) $\vee$ F.
#
# x $\wedge$ T = x en x $\vee$ F = x, y en z kunnen dus eigenlijk weggelaten worden wat leidt tot:
#
# f = $\neg$x
#
# x is wel variabel maar kan weer worden opgesplitst in:
#
# - x = (xy $\vee$ xz)
#     - xy = p $\vee$ ($\neg$q)
#     - xz = p $\wedge$ ($\neg$q)
#
# xz is eigenlijk overbodig omdat xy een disjunction is en xz een conjunction, waardoor xy altijd T is als xz T is, maar xy ook vaker T is dan xz, dus:
#
# x = p $\vee$ ($\neg$q)
#
# f = $\neg$(p $\vee$ ($\neg$q))
#
# f is logically equivallent aan de contrapositive van f, namelijk:
#
# f = ($\neg$p) $\wedge$ q
#
# Toevallig was dit dezelfde proposition als bij opdracht 16.2 en dus is de truthtable hetzelfde.
#
# ### 16.4
#
# Question: Write a proposition that is logically equivalent to $\neg$($\neg$p)
#
# Answer: p
#
# ### 16.5
#
# Question: Write a proposition that is logically equivalent to (($\neg$q) $\vee$ ($\neg$(r $\vee$ ($\neg$q)))) $\rightarrow$ ($\neg$( ($\neg$q) $\leftrightarrow$ ($\neg$( ($\neg$q) $\vee$ r))))
#
# Answer:
#
# f = (($\neg$q) $\vee$ ($\neg$(r $\vee$ ($\neg$q)))) $\rightarrow$ ($\neg$( ($\neg$q) $\leftrightarrow$ ($\neg$( ($\neg$q) $\vee$ r))))
#
# f = (x) $\vee$ (y)
#
# - x = ($\neg$(xy $\vee$ xz))
#     - xy = ($\neg$q)
#     - xz = ($\neg$(r $\vee$ ($\neg$q))) = ($\neg$r) $\wedge$ q
#         - x = (q $\wedge$ (r $\vee$ ($\neg$q))): **T als q = T en r = T**
#
# - y = ((($\neg$yx) $\vee$ ($\neg$yz)) $\wedge$ (yx $\vee$ yz))))
#     - yx = ($\neg$q)
#     - yz = (q $\wedge$ ($\neg$r))
#         - y = (($\neg$q) $\vee$ (q $\wedge$ ($\neg$r)))): **T als q = F of (q = T en r = F)**
#
# dus rekening houdend met het feit dat x of y T moet zijn al wilt f T zijn:
#
# f = T
