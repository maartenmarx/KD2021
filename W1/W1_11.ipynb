# %% [markdown]
# # Assignment Netwerkanalyse

# %% [markdown]
# ## Notebook made by
#
#
# |Naam|Studentnummer|
# |-|-|
# |Robin|secret|
# |Matthijs|secret|
# |Thomas|secret|
# |Thomas|secret|
#
# ## Peerreview
#
# * Vul onderstaande dict/tabel in en run de cel. Klopt het? Zijn jullie het er allemaal mee eens?
#     * Verander `1,2,3,4` door jullie studentnummers
#     * `1: {1:.2,2:.3,3:.3,4:.2}` betekent dat student 1 zijn punt zo over de 4 studenten verdeelt
#     * Let op, per student moeten de punten optellen tot 1!
#     * De gegeven punten staan in de tabel op de rijen, de ontvangen punten in de kolommen.
#     * met `cijfer_per_student` kan je bepalen welk cijfer ieder krijgt bij een gegeven groepscijfer.

# %% [markdown]
# ## Toelichting
#
# * De meeste opgaven worden automatisch nagekeken. Bij vrijwel alle opdrachten staan er een paar tests onder de opdracht, dit is voornamelijk om te zorgen dat je de juiste type output geeft. Dit zijn dus *NIET* alle tests, die komen er bij het graden nog bij.
# * Elke vraag is 1 punt waard, tenzij anders aangegeven. Soms is die punt onderverdeeld in deelpunten, maar niet altijd.
#
# ## Voor het inleveren!
#
# * Pas niet de cellen aan, vooral niet die je niet kunt editen. Dit levert problemen op bij nakijken. Twijfel je of je per ongeluk iets hebt gewijzigd, kopieer dan bij inleveren je antwoorden naar een nieuw bestand, zodat het niet fout kan gaan.
#
# * Zorg dat de code goed runt van boven naar beneden, verifieer dat door boven in Kernel -> Restart & Run All uit te voeren
#
# ## Na het inleveren!
#
# * Het gebeurt erg vaak dat mensen een "leeg bestand" inleveren. Vaak een andere versie van de opgave die nog ergens op je computer rondslingerde. Zonde van al je werk toch!
# * Dus, lever **minstens een half uur voor tijd in**. Download dan wat je hebt ingeleverd op Canvas. Geef het een andere naam om verwarring te voorkomen. En draai alle cellen, en bekijk het. Geen syntax fouten? Alle vragen gemaakt? Dan zit het vast wel goed, en hoef je niet in de zenuwen te zitten.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Assignment-Netwerkanalyse" data-toc-modified-id="Assignment-Netwerkanalyse-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Assignment Netwerkanalyse</a></span><ul class="toc-item"><li><span><a href="#Notebook-made-by" data-toc-modified-id="Notebook-made-by-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Notebook made by</a></span></li><li><span><a href="#Peerreview" data-toc-modified-id="Peerreview-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Peerreview</a></span></li><li><span><a href="#Toelichting" data-toc-modified-id="Toelichting-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Toelichting</a></span></li><li><span><a href="#Voor-het-inleveren!" data-toc-modified-id="Voor-het-inleveren!-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Voor het inleveren!</a></span></li><li><span><a href="#Na-het-inleveren!" data-toc-modified-id="Na-het-inleveren!-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Na het inleveren!</a></span></li></ul></li><li><span><a href="#Prop-logic-1-(10pt)" data-toc-modified-id="Prop-logic-1-(10pt)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Prop logic 1 (10pt)</a></span><ul class="toc-item"><li><span><a href="#Jullie-opdracht" data-toc-modified-id="Jullie-opdracht-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Jullie opdracht</a></span><ul class="toc-item"><li><span><a href="#Beoordeling" data-toc-modified-id="Beoordeling-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Beoordeling</a></span></li></ul></li></ul></li><li><span><a href="#Prop-logic-2-(0pt)" data-toc-modified-id="Prop-logic-2-(0pt)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Prop logic 2 (0pt)</a></span></li></ul></div>

# %% [markdown]
# # Prop logic 1 (10pt)
#
# Met 2 variabelen `p` en `q` kan je natuurlijk oneindig veel verschillende formules maken.
# **Laat dat zien met wat voorbeelden. Het geeft niet als ze flauw zijn.**
# Maar je kan maar 16 verschillende waarheidstafels maken. Hieronder staat er eentje. Omdat je vier vakjes met T en F (2 waarden) kunt invullen, zijn er dus $2^4$ verschillende tafels te maken. **Voor welke formule is deze tafel?**  (helemaal onderaan staat het antwoord)
#
#
# |  | P True  | P False|
# | --- | --- | --- |
# | **Q True** | T | F |
# | **Q False** | T | T |
#
# ## Jullie opdracht
#
# Maak een prachtig uitziend, helder geordend overzicht van deze 16 tabellen, en geef bij elke tabel de formule die exact de betekenis heeft gegeven door die tabel. **Je formule mag alleen $p,q,\neg,\rightarrow,\leftrightarrow$ bevatten.**
#
# Je mag het in Markdown en LaTeX doen, maar ook met de hand tekenen, en schilderen.  Maak je iets met de hand, maak dan een goede foto, zet die ergens op het web, en link ernaar in je Markdown antwoord. Als je naar de code van deze cel kijkt, zie je hoe je in MarkDown een link naar een plaatje maakt.
#
# ![A tableaux proof for the propositional formula ((a ∨ ¬b) ∧ b) → a.](https://upload.wikimedia.org/wikipedia/commons/thumb/2/21/Prop-tableau-4.svg/300px-Prop-tableau-4.svg.png)
#
# ### Beoordeling
#
# * Het is super eenvoudig om in Python te checken of je antwoord correct is.
# * Een antwoord met dus ook maar 1 fout erin is dan dus ook onvoldoende.
# * De hoogte van je voldoende wordt bepaald door de schoonheid en overzichtelijkheid van je werk, en de elegantie van de gekozen formules.
#
#
#
# $q\rightarrow p$

# %% [markdown]
# # Alle mogelijkheden:
#
# 1.
# $p\rightarrow p$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | T | T |
# | **Q False** | T | T |
#
# 2.
# $q\rightarrow p$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | T | F |
# | **Q False** | T | T |
#
# 3.
# $q\rightarrow \neg p$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | F | T |
# | **Q False** | T | T |
#
# 4.
# $\neg q\rightarrow \neg p$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | T | T |
# | **Q False** | F | T |
#
# 5.
# $\neg q\rightarrow p$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | T | T |
# | **Q False** | T | F |
#
# 6.
# $q \rightarrow \neg q$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | F | F |
# | **Q False** | T | T |
#
# 7.
# $\neg q \rightarrow q$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | T | T |
# | **Q False** | F | F |
#
# 8.
# $\neg p \rightarrow p$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | T | F |
# | **Q False** | T | F |
#
# 9.
# $p\rightarrow \neg p$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | F | T |
# | **Q False** | F | T |
#
# 10.
# $q\leftrightarrow p$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | T | F |
# | **Q False** | F | T |
#
# 11.
# $\neg q\leftrightarrow p$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | F | T |
# | **Q False** | T | F |
#
# 12.
# $\neg ( q \rightarrow \neg p )$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | T | F |
# | **Q False** | F | F |
#
# 13.
# $\neg (\neg q \rightarrow \neg p )$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | F | F |
# | **Q False** | T | F |
#
# 14.
# $\neg (\neg q \rightarrow p )$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | F | F |
# | **Q False** | F | T |
#
# 15.
# $\neg ( q \rightarrow p )$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | F | T |
# | **Q False** | F | F |
#
# 16.
# $\neg p\leftrightarrow p$
#
# |  | P True  | P False|
# | :-: | :-: | :-: |
# | **Q True** | F | F |
# | **Q False** | F | F |

# %% [markdown]
# # Prop logic 2 (0pt)
#
# Maak  opgaven 16.1-16.5 in <https://www.stat.berkeley.edu/~stark/SticiGui/Text/logic.htm>.
#
# De antwoorden staan erbij, behalve bij 16.1, maar die zijn makkelijk met behulp van de waarheidstafels voor de connectieven te checken.
#
# Een goede manier is om alle opgaven zelf te maken, en ze dan in je groepje te bespreken en te vergelijken. Zo moet je wel tot de juiste antwoorden komen. Geef niet alleen het antwoord maar ook een heldere uitleg waarom je dat antwoord geeft.
#
# Bijvoorbeeld: *4 is prima and $-1\times -1= -1$* is niet waar want $-1\times -1= -1$ is niet waar en een conjunctie (*and*) is onwaar als 1 van de conjuncten (de delen) onwaar is.
#
# **Tip** als je de pagina ververst krijg je soms weer andere opdrachten.
#
# Copieer je antwoorden in de cel hieronder.
#
# **Hint** Denk nou niet, he 0 punten, dus dat is zinloos om te doen. Nee, want op het tentamen stikt het van dit soort puzzeltjes. Het is echt oefenen wil je daar handig en foutloos in worden.

# %%
# YOUR CODE HERE

#
#
#raise NotImplementedError()

# %% [markdown]
# ## **Exercise 16-1**
#
# Which of the following propositions are true (Select all that are.)
#
# * **<span style="color:green">the U.S.A. elected its first Hawaiian president in 2008 | the moon is made of cheese</span>**<br>Barack Obama was de eerste Amerikaanse president die uit Hawaii kwam en werd verkozen in 2008. De stelling vraagt of slechts een van de twee true is en daarom is de gehele stelling true
# * **<span style="color:green">3 is an odd number</span>**<br>Wanneer je een getal door het getal 2 kunt delen en het resterende getal 0 is, is een getal volgens de wiskunde een even getal. Andersom heb je ook een oneven getal, wanneer er wel een restwaarde is. In het geval van 3 is de restwaarde 1. 3 is dus een oneven getal en de stelling is daardoor true.
# * **<span style="color:red">Homer Simpson is President of the U.S.A. & the U.S.A. elected its first Hawaiian president in 2008</span>**<br>Homer Simpson is niet de U.S. President, dus het statement is false.
# * **<span style="color:red">the moon is made of cheese</span>**<br> which is ofcourse a false statement
# * **<span style="color:red">Homer Simpson is President of the U.S.A. | -1$\times$-1=-1</span>**<br> Homer Simpson is niet de president van Amerika. Daarnaast is -1 $\times$ -1 ook niet gelijk aan -1. Gezien beide stellingen false zijn is de gehele stelling false
# * **<span style="color:green">Homer Simpson is President of the U.S.A. $\rightarrow$ -1$\times$-1=-1</span>**<br> Homer Simpson is niet de president van Amerika. Echter staat er in dit geval false implies (false $\rightarrow$) wat altijd tot een true leidt. Ondanks de false stelling is de gehele stelling wel true
# * **<span style="color:green">Homer Simpson is President of the U.S.A. $\rightarrow$ 4 is a perfect square</span>**<br> Hier geldt hetzelfde als bij de voorgaande. False implies leidt alijd tot een true.
# * **<span style="color:green">4 is a perfect square</span>**<br> Een perfect kwadraat is een getal dat uitgedrukt kan worden als een macht van een ander getal in het zelfde numerieke systeem. Bij het getal vier kan dit: 2<sup>2</sup> = 4. Hierdoor klopt de stelling.
# * **<span style="color:red">-1$\times$-1=-1 & 4 is prime </span>**<br> -1$\times$-1 is niet gelijk aan -1. Hierdoor klopt de eerste helft van de stelling niet, wat het onmogelijk maakt om beide kanten van de stellin gkloppend te krijgen. De stelling is hierdoor false.
# * **<span style="color:green">3 is an odd integer $\rightarrow$ 4 is a perfect square</span>**<br>Wanneer je drie deelt door 2 heb je een restwaarde van 1. Zoals boven besproken betekent dit dat 3 een oneven getal is. Zoals ook eerder besproken is 4 de macht van 2, welke in het zelfde numerieke systeem zit als 4. Deze stelling staat dus voor true $\rightarrow$ true, wat resulteert in een true.
# * **<span style="color:green">2+2 = 4 & 3 is an odd integer</span>**<br> Beide kanten van het &-teken zijn true. 2+2 = 4 en 3 is een oneven getal, want wanneer je het door 2 deelt heb je een restwaarde over.
# * **<span style="color:red">3 is an odd integer $\rightarrow$ the moon is made of cheese</span>**<br> Deze stelling resulteert in het volgene true $\rightarrow$ false, wat resulteert in een false. 3 is inderdaad een oneven getal, maar het is nog niet bewezen dat de maan van kaas gemaakt is.

# %% [markdown]
# ## **Exercise 16.2**
#
# **(($\neg$(*p* $\leftrightarrow$ *p*)) $\rightarrow$ ( ($\neg$*q*) $\vee$ ($\neg$*q*))) $\vee$ ($\neg$(*p* $\wedge$ *q*))) $\rightarrow$ ($\neg$(*p* $\wedge$ *q*))**
#
# bovenstaande stelling delen we op in kleine stukken waarvan we stukje bij beetje de waardes van onderzoeken. De verdeling van de stukken ziet er als volgt uit:
#
# **( 1 $\rightarrow$ 2) $\vee$ 3 ) $\rightarrow$ 4**
#
# De formules met hun waarheidstabellen worden hier onder uitgewerkt:
#
# * **1: ($\neg$(*p* $\leftrightarrow$ *p*))**
#
# |  P | Q | $\neg$(*p* $\leftrightarrow$ p)  | |
# |  :-: |  :-: |  :-: |  :-: |
# | T | T | F| |
# | F | F | F | |
# | T | T | F | |
# | F | F | F | |
#
# * **2: ( ($\neg$*q*) $\vee$ ($\neg$*q*))**
#
# |  P | Q | (($\neg$*q*) $\vee$ ($\neg$*q*))  |
# |  :-: |  :-: |  :-: |
# | T | T | F |
# | F | F | T |
# | T | T | F |
# | F | F | T |
#
# * **3: ($\neg$(*p* $\wedge$ *q*))**
#
# |  P | Q | ($\neg$(*p* $\wedge$ *q*))  |
# |  :-: |  :-: |  :-: |
# | T | T | F |
# | F | F | T |
# | T | T | T |
# | F | F | T |
#
# * **4: ($\neg$(*p* $\wedge$ *q*)**
#
# |  P | Q | ($\neg$(*p* $\wedge$ *q*))  |
# |  :-: |  :-: |  :-: |
# | T | T | F |
# | F | F | T |
# | T | T | T |
# | F | F | T |
#
# * **Totaal abstract:( 1 $\rightarrow$ 2) $\vee$ 3 ) $\rightarrow$ 4**
#
#
# |  P | Q | 1 $\rightarrow$ 2  | 1 $\rightarrow$ 2 $\vee$ 3 | ( 1 $\rightarrow$ 2) $\vee$ 3 ) $\rightarrow$ 4 |
# |  :-: |  :-: |  :-: | :-: | :-:
# | T | T | T | T | F |
# | F | F | T | T | T |
# | T | T | T | T | T |
# | F | F | T | T | T |
#
# * **Totale formule: (($\neg$(*p* $\leftrightarrow$ *p*)) $\rightarrow$ ( ($\neg$*q*) $\vee$ ($\neg$*q*))) $\vee$ ($\neg$(*p* $\wedge$ *q*))) $\rightarrow$ ($\neg$(*p* $\wedge$ *q*))**
#
# |  P | Q | (($\neg$(*p* $\leftrightarrow$ *p*)) $\rightarrow$ ( ($\neg$*q*) $\vee$ ($\neg$*q*))) $\vee$ ($\neg$(*p* $\wedge$ *q*))) $\rightarrow$ ($\neg$(*p* $\wedge$ *q*)) |
# |  :-: |  :-: |  :-: |
# | T | T | F |
# | F | F | T |
# | T | T | T |
# | F | F | T |

# %% [markdown]
# ## **Exercise 16.3**
#
# **Stelling:**
#
# **($\neg$( ( ($\neg$( ($\neg$*q*) $\leftrightarrow$ ($\neg$*q*))) $\wedge$ ( ($\neg$*p*) $\vee$ *p*)) $\rightarrow$ ( ($\neg$( ($\neg$*p*) $\vee$ ($\neg$*q*))) & ($\neg$(*q* & *q*))))) $\rightarrow$ ( ($\neg$( ($\neg$*p*) $\vee$ ($\neg$*q*))) $\wedge$ ($\neg$(*q* & *q*)))**
#
# Bovenstaande propositie is *logically equivalent* aan T. Uitwerken in waarheidstabel geeft:
#
# |  P | Q | ($\neg$( ( ($\neg$( ($\neg$*q*) $\leftrightarrow$ ($\neg$*q*))) $\wedge$ ( ($\neg$*p*) $\vee$ *p*)) $\rightarrow$ ( ($\neg$( ($\neg$*p*) $\vee$ ($\neg$*q*))) & ($\neg$(*q* $\wedge$ *q*))))) $\rightarrow$ ( ($\neg$( ($\neg$*p*) $\vee$ ($\neg$*q*))) & ($\neg$(*q* $\wedge$ *q*))) |
# |  :-: |  :-: |  :-: |
# | T | T | T |
# | F | F | T |
# | T | F | T |
# | F | T | T |

# %% [markdown]
# ## **Exercise 16.4**
#
# **Stelling:**
#
# **Write a proposition that is logically equivalent to ( ($\neg$q)  $\vee$ (p  $\vee$ ($\neg$q))) $\rightarrow$ ($\neg$(p  $\vee$ ($\neg$q))) using only p, q, T, F, and the fundamental logical operations !, | and &. Do not use ↔ or →.**
#
# Hier zijn veel mogelijkheden en uitkomsten voor, maar een simpele uitvoering van de door ons gekozen propositie is:
# **$\neg$*p* $\wedge$ *q***

# %% [markdown]
# ## **Exercise 16.5**
#
# **Stelling:**
#
# **Write a proposition that is logically equivalent to !( (!( ( (!q) → q) ↔ ( (!r) & r))) ↔ (r & r)) using only p, q, r, T, F, and the fundamental logical operations !, | and &. Do not use ↔ or →.**
#
# Voor deze stelling zijn ook veel uitkomsten mogelijk. Wij hebben voor onderstaande propositie gekozen:
#
# **$\neg$(((( $\neg$((((( $\neg$( $\neg$(q)) $\vee$ (q))) $\wedge$ (( $\neg$(r)) & (r))) $\vee$ ( $\neg$(( $\neg$( $\neg$(q)) $\vee$ (q))) $\wedge$ $\neg$(( $\neg$(r)) $\wedge$ (r)))))) $\wedge$ ((r) & (r))) $\vee$ ( $\neg$( $\neg$((((( $\neg$( $\neg$(q)) $\vee$ (q))) $\wedge$ (( $\neg$(r)) $\wedge$ (r))) $\vee$ ( $\neg$(( $\neg$( $\neg$(q)) $\vee$ (q))) $\wedge$ $\neg$(( $\neg$(r)) $\wedge$ (r)))))) $\wedge$ $\neg$((r) $\wedge$ (r)))))**
