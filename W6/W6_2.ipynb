# %% [markdown]
# # Assignment Kennis en Data

# %% [markdown]
# ## Notebook made by
#
#
# |Naam|Studentnummer|
# |-|-|
# |Kyle| secret|
# |Nick| secret|
# |Shilpa| secret |
# | | |
#
# ## Peerreview
#
# * Vul onderstaande dict/tabel in en run de cel. Klopt het? Zijn jullie het er allemaal mee eens?
#     * Verander `1,2,3,4` door jullie studentnummers
#     * `1: {1:.2,2:.3,3:.3,4:.2}` betekent dat student 1 zijn punt zo over de 4 studenten verdeelt
#     * Let op, per student moeten de punten optellen tot 1!
#     * De gegeven punten staan in de tabel op de rijen, de ontvangen punten in de kolommen.
#     * met `cijfer_per_student` kan je bepalen welk cijfer ieder krijgt bij een gegeven groepscijfer.

# %% [markdown]
# ## Toelichting
#
# * De meeste opgaven worden automatisch nagekeken. Bij vrijwel alle opdrachten staan er een paar tests onder de opdracht, dit is voornamelijk om te zorgen dat je de juiste type output geeft. Dit zijn dus *NIET* alle tests, die komen er bij het graden nog bij.
# * Elke vraag is 1 punt waard, tenzij anders aangegeven. Soms is die punt onderverdeeld in deelpunten, maar niet altijd.
#
# ## Voor het inleveren!
#
# * Pas niet de cellen aan, vooral niet die je niet kunt editen. Dit levert problemen op bij nakijken. Twijfel je of je per ongeluk iets hebt gewijzigd, kopieer dan bij inleveren je antwoorden naar een nieuw bestand, zodat het niet fout kan gaan.
#
# * Zorg dat de code goed runt van boven naar beneden, verifieer dat door boven in Kernel -> Restart & Run All uit te voeren
#
# ## Na het inleveren!
#
# * Het gebeurt erg vaak dat mensen een "leeg bestand" inleveren. Vaak een andere versie van de opgave die nog ergens op je computer rondslingerde. Zonde van al je werk toch!
# * Dus, lever **minstens een half uur voor tijd in**. Download dan wat je hebt ingeleverd op Canvas. Geef het een andere naam om verwarring te voorkomen. En draai alle cellen, en bekijk het. Geen syntax fouten? Alle vragen gemaakt? Dan zit het vast wel goed, en hoef je niet in de zenuwen te zitten.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Assignment-Kennis-en-Data" data-toc-modified-id="Assignment-Kennis-en-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Assignment Kennis en Data</a></span><ul class="toc-item"><li><span><a href="#Notebook-made-by" data-toc-modified-id="Notebook-made-by-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Notebook made by</a></span></li><li><span><a href="#Peerreview" data-toc-modified-id="Peerreview-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Peerreview</a></span></li><li><span><a href="#Toelichting" data-toc-modified-id="Toelichting-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Toelichting</a></span></li><li><span><a href="#Voor-het-inleveren!" data-toc-modified-id="Voor-het-inleveren!-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Voor het inleveren!</a></span></li><li><span><a href="#Na-het-inleveren!" data-toc-modified-id="Na-het-inleveren!-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Na het inleveren!</a></span></li></ul></li><li><span><a href="#RDF-en-RDFS-completion" data-toc-modified-id="RDF-en-RDFS-completion-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>RDF en RDFS completion</a></span><ul class="toc-item"><li><span><a href="#Jouw-taak" data-toc-modified-id="Jouw-taak-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Jouw taak</a></span><ul class="toc-item"><li><span><a href="#Je-cijfer-is-gebaseerd-op" data-toc-modified-id="Je-cijfer-is-gebaseerd-op-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Je cijfer is gebaseerd op</a></span></li><li><span><a href="#Voorwaarden" data-toc-modified-id="Voorwaarden-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Voorwaarden</a></span><ul class="toc-item"><li><span><a href="#Database-en-regels" data-toc-modified-id="Database-en-regels-2.1.2.1"><span class="toc-item-num">2.1.2.1&nbsp;&nbsp;</span>Database en regels</a></span></li><li><span><a href="#Test-voorbeelden" data-toc-modified-id="Test-voorbeelden-2.1.2.2"><span class="toc-item-num">2.1.2.2&nbsp;&nbsp;</span>Test voorbeelden</a></span></li><li><span><a href="#Check-ajb" data-toc-modified-id="Check-ajb-2.1.2.3"><span class="toc-item-num">2.1.2.3&nbsp;&nbsp;</span>Check ajb</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Jouw-completion-functie" data-toc-modified-id="Jouw-completion-functie-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Jouw completion functie</a></span></li><li><span><a href="#Jouw-lijst-met-testen" data-toc-modified-id="Jouw-lijst-met-testen-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Jouw lijst met testen</a></span></li><li><span><a href="#Voor-de-echte-diehards-die-gaan-voor-een-10" data-toc-modified-id="Voor-de-echte-diehards-die-gaan-voor-een-10-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Voor de echte diehards die gaan voor een 10</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Hoeveel-RDFS-statements-zijn-er-eigenlijk-die-zouden-kunnen-volgen?" data-toc-modified-id="Hoeveel-RDFS-statements-zijn-er-eigenlijk-die-zouden-kunnen-volgen?-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Hoeveel RDFS statements zijn er eigenlijk die zouden kunnen volgen?</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # RDF en RDFS completion
#
# * We maken een programma dat gegeven een RDF triple store plus een set RDFS statements, alle mogelijke niet triviale logische consequenties hiervan afleidt, en die in een RDF en RDFS database zet.
# * Dit wordt ook wel *materialization* genoemd. Het idee is dat uit beide kennisbanken **exact dezelfde feiten volgen**, maar dat dat sneller kan vanuit de pure RDF versie (omdat je dan geen feiten hoeft af te leiden).
# * De technische term voor het algorithme dat deze "completering" doet is de *chase*.
# * Het [artikel van Enrico Franconi et al](https://link.springer.com/chapter/10.1007/978-3-642-41335-3_7) bevat een systeem.
# * Net als in Franconi werken we alleen met de 4 interresantste RDFS statements:
#     * **Hierarchie**
#         * $\forall xy (Rxy \rightarrow Sxy)$  (" to love him is to know him", als je van iemand houdt dan ken je diegene)
#         * $\forall x (Horse(x) \rightarrow Animal(x))$
#     * **Domain en range restrictions**
#         * $\forall xy (Rxy \rightarrow Dx)$ (domain) "Als x een staart heeft is het een dier"
#         * $\forall xy (Rxy \rightarrow Dy)$ (range)  "Als je een  ouder bent van y, is y een mens."
#
# ## Jouw taak
#
# 1. Maak de functie `complete(facts, rules)` die voldoet aan de volgende eigenschap:
#     * voor elke feit `(o,p,s)`, facts+rules $\models$ (o,p,s) $\Leftrightarrow$ `complete(facts, rules)` $\models$ (o,p,s)
#         * Jouw functie is zowel volledig als geldig (*sound and complete*), dat is exact wat je wilt.
#     * `complete(facts, rules)` is een verzameling feiten.
# 2. Maak een flinke collectie van tests waarmee je test dat jouw functie aan die eisen voldoet.
#     * Dus dat het niet te veel en niet te weinig, maar exact de juiste feiten impliceert.
#     * Je deelt die tests met alle anderen, en ook jouw functie, en we gaan dus elke functie tegen elke test draaien, en dus een matrix met scores maken.
#
# ### Je cijfer is gebaseerd op
#
# 1. Hoe goed doorstaat jouw functie alle tests.
# 2. Hoe goed zijn jouw tests.
#     * Strenge (doch rechtvaardige) tests zijn natuurlijk het best. Tests waar iedereen voor slaagt lijken leuk maar zijn meestal niet veel waard.
#
#
# ### Voorwaarden
#
# #### Database en regels
#
# We werken niet direct met RDF en RDFS omdat dat zo'n enorme syntax overhead heeft. We doen de dingen gewoon lekker in Python.
#
# * Je RDF store is een verzameling triples, waarbij de 3 elementen strings of integers of floats zijn.
#     * Je schrijft eigenschappen van individuen als `('henk', 'isa', 'Man')`
#         * dus altijd met de vaste relatie `isa` in het midden.
#     * en relaties tussen individuen als `('henk', Houdt_van', 'ingrid')`
#     * en idem voor relaties tussen individuen en getallen `('henk', 'leeftijd', 53)`
#     * Begin namen van individuen ("knopen") meteen kleine letter, en eigenschappen en relaties met een grote.
# * Je RDFS store is een dict met sleutels `['subPropertyOf', 'subClassOf', 'domain', 'range']` en voor elke sleutel een verzameling met 2-tuples (paartjes in gewoon Nederlands) als waarde.
#
# #### Test voorbeelden
#
# Een testset is een lijst triples van de vorm `(D:RDF_store, R:RDFS_store, Pos:RDF_store, Neg:RDF_store)` waarvoor geldt dat
# * voor elk triple t in Pos: $D,R\models t$
# * voor elk triple t in Neg: $D,R\not\models t$
# * Met $\models$ wordt dus bedoeld volgens de Franconi semantiek, en dus ook volgens de RDF semantiek. Dat betekent dus niet per se dat dit hetzelfde is als volgens jouw completion functie (want die zou fouten kunnen maken).
# * Hieronder staat een flauw voorbeeld. Jounes is veel gaver en strenger en leuker  natuurlijk!
#
# #### Check ajb
#
# * Als de tests hieronder niet slagen kunnen we niks met je code, en kan je  dus niet meedoen. Zonde van al je werk toch?

# %%
# voorbeeld
RDFS= {'subPropertyOf': {('Houdt_van','Kent'), ('Eet','Vindt_lekker')},
      'subClassOf': {('Mens','Dier'),('Student','Mens')},
      'domain': {('Houdt_van','Mens')},
      'range': ('Vindt_lekker','Eten')}
RDFS
# Out:
# {'subPropertyOf': {('Eet', 'Vindt_lekker'), ('Houdt_van', 'Kent')},
#  'subClassOf': {('Mens', 'Dier'), ('Student', 'Mens')},
#  'domain': {('Houdt_van', 'Mens')},
#  'range': ('Vindt_lekker', 'Eten')}

# %%
# voorbeeld

test1= [
    ({('Henk','isa','Mens')},  # RDF store
       {'subPropertyOf': set(),  # RDFS store
      'subClassOf': {('Mens','Sterfelijk')},
      'domain': set(),
      'range':  set()},
       {('Henk','isa','Sterfelijk')}, # positieve voorbeelden
       {('henk', 'Houdt_van', 'ingrid')} # negatieve voorbeelden
       )
       ]
test1
# Out:
# [({('Henk', 'isa', 'Mens')},
#   {'subPropertyOf': set(),
#    'subClassOf': {('Mens', 'Sterfelijk')},
#    'domain': set(),
#    'range': set()},
#   {('Henk', 'isa', 'Sterfelijk')},
#   {('henk', 'Houdt_van', 'ingrid')})]

# %% [markdown]
# # Jouw completion functie

# %%
from typing import List, Tuple, Set, Union, Dict

# Python type hints for convenience
Number = Union[int, float]
Triple = Tuple[Union[str, Number], Union[str, Number], Union[str, Number]]
Rdf = Set[Triple]
Rdfs = Dict[str, Set[Tuple]]
Positives = Set[Triple]
Negatives = Set[Triple]
Test = Tuple[Rdf, Rdfs, Positives, Negatives]

# jouw functie
def complete_12272302(facts: Rdf, rules: Rdfs):
    
    # List of facts to process.
    # New facts which are discovered are to be thrown in here.
    # We use a list instead of a set so that we can append items while looping over it. This wouldn't work with a set.
    facts_worklist = list(facts)

    # Keep processing worklist until it's empty
    for subject, predicate, _object in facts_worklist:

        # Initialise list of new facts which we will perhaps discover during this iteration.
        new_facts: List[Triple] = []

        # Analyse current fact using rules as defined in Rdfs. New facts might be deduced during this process.
        for rule in filter(lambda r: predicate in r, rules["subPropertyOf"]):
            new_facts.append((subject, rule[1], _object))

        for rule in filter(lambda r: _object in r, rules["subClassOf"]):
            new_facts.append((subject, predicate, rule[1]))

        for rule in filter(lambda r: predicate in r, rules["domain"]):
            new_facts.append((subject, "isa", rule[1]))

        for rule in filter(lambda r: predicate in r, rules["range"]):
            new_facts.append((subject, predicate, rule[1]))

        # Add new facts on top of stack, so that they also get processed at some point.
        # Do not add those that have already been added.
        facts_worklist += filter(lambda f: f not in facts_worklist, new_facts)

    # Return all facts that have been analysed (which is also the full list of facts).
    # Conversion to set is actually redundant, as our algorithm prevents duplication in and of itself.
    return set(facts_worklist)

# %%
assert studnr!= 1234567, 'Dit is niet jouw student nummer!'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f87a69b3ffdb> in <module>
# ----> 1 assert studnr!= 1234567, 'Dit is niet jouw student nummer!'
#
# NameError: name 'studnr' is not defined

# %%
RDFS= {'subPropertyOf': {('Houdt_van','Kent'), ('Eet','Vindt_lekker')},
      'subClassOf': {('Mens','Dier'),('Student','Mens')},
      'domain': {('Houdt_van','Mens')},
      'range': ('Vindt_lekker','Eten')}
RDF= {('Henk','isa','Mens')}
completion= functienaam(RDF,RDFS)
assert isinstance(completion,set)
for t in completion:
    assert isinstance(t,tuple)
    assert len(t)==3
    assert isinstance(t[0], str)
    assert isinstance(t[1], str)
    assert isinstance(t[2], (str, int,float))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f784c402e67c> in <module>
#       4       'range': ('Vindt_lekker','Eten')}
#       5 RDF= {('Henk','isa','Mens')}
# ----> 6 completion= functienaam(RDF,RDFS)
#       7 assert isinstance(completion,set)
#       8 for t in completion:
#
# NameError: name 'functienaam' is not defined

# %% [markdown]
# # Jouw lijst met testen

# %%
testnaam= 'test_'+str(12272302)


test0 = ({('jerry', 'isa', 'Muis'),
          ('tom', 'isa', 'Kat'),
          ('jerry', 'Haat', 'tom')}, # RDF store
          {'subPropertyOf': {('Haat', 'Vermijden')}, # RDFS store
          'subClassOf': {('Kat', 'Dier'), ('Muis', 'Dier'), ('Dier', 'Organisme'), ('Organisme', 'LevendOfDood')},
          'domain': {('Haat', 'Levend')},
          'range':  set()},
          {('jerry', 'Vermijden', "tom")}, # positieve voorbeelden
        {('tom', 'isa', 'Muis')} # negatieve voorbeelden
        ) 
    

test1= ({('henk','isa','Mens')},  # RDF store
         {'subPropertyOf': set(),  # RDFS store
         'subClassOf': {('Mens','Sterfelijk')},
         'domain': set(),
         'range':  set()},
         {('henk','isa','Sterfelijk')}, # positieve voorbeelden
         {('henk', 'Houdt_van', 'ingrid')} # negatieve voorbeelden
        )
        
       
test2= ({('henk', 'Houdt_van', 'ingrid' )},  # RDF store
         {'subPropertyOf': {('Houdt_van','Kent')},  # RDFS store
         'subClassOf': {('Mens','Sterfelijk')},
         'domain': {('Houdt_van','Mens')},
         'range':  set()},
         {('henk','isa','Mens')}, # positieve voorbeelden
         {('henk', 'Houdt_van', 'Mens')} # negatieve voorbeelden
        )
       
       
test3 = ({('bert', 'isa', 'Man'), ('bert', 'Houdt_van', 'ernie')},   # RDF store
          {'subPropertyOf': {('Houdt_van','Kent')},  # RDFS store
          'subClassOf': {('Mens','Sterfelijk'), ('Man', 'Mens')},
          'domain': set(),
          'range':  {('Houdt_van', 'Iemand')}},
          {('bert','isa','Mens')}, # positieve voorbeelden
          {('ernie', 'Houdt_van', 'bert')} # negatieve voorbeelden
         )
        

test4 = ({('hans', 'Houdt_van', 'grietje'), ('hans', 'isa', 'Gay'),
          ('grietje', 'heeft', 'Er_Genoeg_Van')},  # RDF store
          {'subPropertyOf': {('Houdt_van','Kent'), ('Kent','Heeft_waargenomen')},  # RDFS store
          'subClassOf': {('Mens','Sterfelijk'), ('Gay', 'Homo'), ('Gay', 'NietHetero'), ('Er_Genoeg_Van', 'Hoeft_Niet_meer')},
          'domain': {('Houdt_van','Mens')},
          'range':  set()},
          {('hans', 'isa', 'Sterfelijk')}, # positieve voorbeelden
          {('grietje', 'isa', 'Gay')} # negatieve voorbeelden
         )
       

test5= ({('grietje', 'Heeft', 'Aids')},
       {'subPropertyOf': set(),  
      'subClassOf': {('Aids', 'Ziekte'), ('Aids', 'Vermoeidheid'), ('Aids', 'Zwak_immuun')},
      'domain': set(),
      'range':  set()}, 
        {('grietje', 'Heeft', 'Ziekte')}, # positieve voorbeelden
        {('Aids', 'Heeft', 'grietje')} # negatieve voorbeelden
        )
       

test6= ({('ludo', 'Vindt_lekker', 'Popcorn'), ('angelique', 'Doet_na', 'Aap')},
        {'subPropertyOf': set(),
         'subClassOf': {('Mens','Sterfelijk'), ('Sterfelijk', 'Levend')},   
         'domain': {('Vindt_lekker', 'Mens'), ('Doet_na', 'Mens')},
         'range':  {('Vindt_lekker', 'Eten')}},
        {('ludo', 'isa', 'Levend')}, # positieve voorbeelden
        {('Eten', 'Vindt_lekker', "Popcorn")} # negatieve voorbeelden
        )
       

test7 = ({('nemo', 'isa', 'Vis'), ('nemo', 'Zwemt', 'Alleen')},  # RDF store
          {'subPropertyOf': {('Zwemt', 'Beweegt')},  # RDFS store
          'subClassOf': {('Vis', 'Dier'), ('Vis','Zwemmer'), ('Vis', 'Blubblub'), ('Alleen', 'Eenzaam')},
          'domain': {('Zwemt', 'In_water')},
          'range':  set()},
          {('nemo', 'isa', 'Blubblub')}, # positieve voorbeelden
          {('Vis', 'isa', 'Zwemmen')} # negatieve voorbeelden
         )
        

test8 = ({('peter', 'isa', 'Duif'), ('peter', 'Vliegt_in', 'Lucht')},  # RDF store
          {'subPropertyOf': {('Vliegt_in', 'Beweegt_in')},  # RDFS store
          'subClassOf': {('Duif','Vogel'), ('Vogel','Dier'), ('Dier','Organisme'), ('Vogel', 'Heeft_Veren'), 
                         ('Vogel', 'Kan_Vliegen'), ('Organisme', 'Bestaat'), ('Lucht', 'The_Universe')},
          'domain': set(),
          'range':  set()},
          {('peter', 'isa', 'Organisme')}, # positieve voorbeelden
          {('peter', 'isa', 'Kip')} # negatieve voorbeelden
         )
        


test9 = ({('bugs_Bunny', 'Pleegt_Een', 'Overval'), ('bugs_Bunny', 'isa', 'Konijn')},  # RDF store
          {'subPropertyOf': set(),  # RDFS store
          'subClassOf': {('Konijn','Knaagdier'), ('Knaagdier','Zoogdier'), ('Zoogdier','Dier'), ('Dier','Organisme'), ('Overval', 'Misdaad')},
          'domain': set(),
          'range':  set()},
          {('bugs_Bunny', 'Pleegt_Een', 'Misdaad')}, # positieve voorbeelden
          {('bugs_Bunny', 'Pleegt_Een', 'Konijn')} # negatieve voorbeelden
         )
        

test10 = ({('beatrix', 'Drinkt', 'Wijn'), ('beatrix', 'isa', 'Elitaire_vrouw'), ('beatrix', 'Was', 'Koningin')},  # RDF store
          {'subPropertyOf': {('Drinkt', 'Neemt_in')},  # RDFS store
          'subClassOf': {('Vrouw', 'Mens'), ('Mens', 'Sterfelijk'), ('Elitaire_vrouw', 'Vet_Gaaf_Persoon')},
          'domain': {('Drinkt', 'Organisme')},
          'range':  {('Drinkt', 'Drank')}},
          {('beatrix', 'Drinkt', 'Drank')}, # positieve voorbeelden
          {('beatrix', 'isa', 'Koningin')} # negatieve voorbeelden
          )
        

test11 = ({('eva', 'Houdt_van', 'Donkerbruine_Mannen'), ('mohamed', 'Eet', 'Baklava'),
           ('günter', 'Isst', 'Sauerkraut'), ('elena', 'Mag_Geen', 'Wasmachine')},  # RDF store
          {'subPropertyOf': {('Eet', 'Vindt_lekker')},  # RDFS store
          'subClassOf': {('Donkerbruine_Mannen', 'Afro_Amerikanen'), ('Wasmachine', 'Apparaat')},
          'domain': {('Houdt_van', 'Mens')},
          'range':  {('Isst', 'Voedsel'), ('Eet', 'Voedsel')}},
          {('mohamed', 'Vindt_lekker', 'Baklava')}, # positieve voorbeelden
          {('mohamed', 'Houdt_van', 'eva')} # negatieve voorbeelden
          )
         

test12= ({('patrick', 'isa', 'Zeester'),
           ('patrick', 'Houdt_Van', 'Spons'), ('spongebob', 'isa', 'Spons')},
         {'subPropertyOf': set(),  
          'subClassOf': {('Zeester', 'Zeedieren'), ('Spons', 'Zeedieren')},
          'domain': {('Houdt_van', 'Organisme')},
          'range':  set()},
          {('patrick', 'isa', 'Zeedieren')}, # positieve voorbeelden
          {('spongebob', 'isa', 'Zeester')} # negatieve voorbeelden
         )
        

test_12272302 = [test0, test1, test2, test3, test4, test5, test6, test7, test8, test9, test10, test11, test12] # zet hier je tests in


for test in test_12272302:
    print(test)
    
    triples = complete_12272302(test[0], test[1])
#     triples = complete_new(test[0], test[1])

    for triple in triples:
        
        print("Triples: ", triple)
    
    for triple in test[2]:
        
        if triple not in triples:
            # Test failed, triple should be in list
            print("Failed_Pos: ", triple)
    for triple in test[3]:
        
        if triple in triples:
            # Test failed, triple should not be in list
            print("Failed_Neg: ", triple)
# Out:
# ({('jerry', 'Haat', 'tom'), ('tom', 'isa', 'Kat'), ('jerry', 'isa', 'Muis')}, {'subPropertyOf': {('Haat', 'Vermijden')}, 'subClassOf': {('Dier', 'Organisme'), ('Muis', 'Dier'), ('Organisme', 'LevendOfDood'), ('Kat', 'Dier')}, 'domain': {('Haat', 'Levend')}, 'range': set()}, {('jerry', 'Vermijden', 'tom')}, {('tom', 'isa', 'Muis')})
# Triples:  ('jerry', 'Vermijden', 'tom')
# Triples:  ('jerry', 'isa', 'Dier')
# Triples:  ('tom', 'isa', 'Organisme')
# Triples:  ('jerry', 'isa', 'Levend')
# Triples:  ('tom', 'isa', 'LevendOfDood')
# Triples:  ('tom', 'isa', 'Kat')
# Triples:  ('jerry', 'isa', 'Muis')
# Triples:  ('jerry', 'Haat', 'tom')
# Triples:  ('jerry', 'isa', 'LevendOfDood')
# Triples:  ('tom', 'isa', 'Dier')
# Triples:  ('jerry', 'isa', 'Organisme')
# ({('henk', 'isa', 'Mens')}, {'subPropertyOf': set(), 'subClassOf': {('Mens', 'Sterfelijk')}, 'domain': set(), 'range': set()}, {('henk', 'isa', 'Sterfelijk')}, {('henk', 'Houdt_van', 'ingrid')})
# Triples:  ('henk', 'isa', 'Sterfelijk')
# Triples:  ('henk', 'isa', 'Mens')
# ({('henk', 'Houdt_van', 'ingrid')}, {'subPropertyOf': {('Houdt_van', 'Kent')}, 'subClassOf': {('Mens', 'Sterfelijk')}, 'domain': {('Houdt_van', 'Mens')}, 'range': set()}, {('henk', 'isa', 'Mens')}, {('henk', 'Houdt_van', 'Mens')})
# Triples:  ('henk', 'Houdt_van', 'ingrid')
# Triples:  ('henk', 'isa', 'Sterfelijk')
# Triples:  ('henk', 'Kent', 'ingrid')
# Triples:  ('henk', 'isa', 'Mens')
# ({('bert', 'isa', 'Man'), ('bert', 'Houdt_van', 'ernie')}, {'subPropertyOf': {('Houdt_van', 'Kent')}, 'subClassOf': {('Man', 'Mens'), ('Mens', 'Sterfelijk')}, 'domain': set(), 'range': {('Houdt_van', 'Iemand')}}, {('bert', 'isa', 'Mens')}, {('ernie', 'Houdt_van', 'bert')})
# Triples:  ('bert', 'Kent', 'ernie')
# Triples:  ('bert', 'isa', 'Mens')
# Triples:  ('bert', 'isa', 'Man')
# Triples:  ('bert', 'Houdt_van', 'Iemand')
# Triples:  ('bert', 'Houdt_van', 'ernie')
# Triples:  ('bert', 'Kent', 'Iemand')
# Triples:  ('bert', 'isa', 'Sterfelijk')
# ({('hans', 'isa', 'Gay'), ('grietje', 'heeft', 'Er_Genoeg_Van'), ('hans', 'Houdt_van', 'grietje')}, {'subPropertyOf': {('Houdt_van', 'Kent'), ('Kent', 'Heeft_waargenomen')}, 'subClassOf': {('Er_Genoeg_Van', 'Hoeft_Niet_meer'), ('Gay', 'NietHetero'), ('Mens', 'Sterfelijk'), ('Gay', 'Homo')}, 'domain': {('Houdt_van', 'Mens')}, 'range': set()}, {('hans', 'isa', 'Sterfelijk')}, {('grietje', 'isa', 'Gay')})
# Triples:  ('hans', 'isa', 'Gay')
# Triples:  ('grietje', 'heeft', 'Hoeft_Niet_meer')
# Triples:  ('hans', 'isa', 'Mens')
# Triples:  ('hans', 'isa', 'NietHetero')
# Triples:  ('hans', 'Kent', 'grietje')
# Triples:  ('grietje', 'heeft', 'Er_Genoeg_Van')
# Triples:  ('hans', 'Houdt_van', 'grietje')
# Triples:  ('hans', 'isa', 'Homo')
# Triples:  ('hans', 'Heeft_waargenomen', 'grietje')
# Triples:  ('hans', 'isa', 'Sterfelijk')
# ({('grietje', 'Heeft', 'Aids')}, {'subPropertyOf': set(), 'subClassOf': {('Aids', 'Zwak_immuun'), ('Aids', 'Ziekte'), ('Aids', 'Vermoeidheid')}, 'domain': set(), 'range': set()}, {('grietje', 'Heeft', 'Ziekte')}, {('Aids', 'Heeft', 'grietje')})
# Triples:  ('grietje', 'Heeft', 'Vermoeidheid')
# Triples:  ('grietje', 'Heeft', 'Ziekte')
# Triples:  ('grietje', 'Heeft', 'Zwak_immuun')
# Triples:  ('grietje', 'Heeft', 'Aids')
# ({('angelique', 'Doet_na', 'Aap'), ('ludo', 'Vindt_lekker', 'Popcorn')}, {'subPropertyOf': set(), 'subClassOf': {('Mens', 'Sterfelijk'), ('Sterfelijk', 'Levend')}, 'domain': {('Doet_na', 'Mens'), ('Vindt_lekker', 'Mens')}, 'range': {('Vindt_lekker', 'Eten')}}, {('ludo', 'isa', 'Levend')}, {('Eten', 'Vindt_lekker', 'Popcorn')})
# Triples:  ('ludo', 'isa', 'Sterfelijk')
# Triples:  ('angelique', 'Doet_na', 'Aap')
# Triples:  ('ludo', 'Vindt_lekker', 'Popcorn')
# Triples:  ('angelique', 'isa', 'Mens')
# Triples:  ('ludo', 'isa', 'Levend')
# Triples:  ('ludo', 'isa', 'Mens')
# Triples:  ('angelique', 'isa', 'Levend')
# Triples:  ('ludo', 'Vindt_lekker', 'Eten')
# Triples:  ('angelique', 'isa', 'Sterfelijk')
# ({('nemo', 'Zwemt', 'Alleen'), ('nemo', 'isa', 'Vis')}, {'subPropertyOf': {('Zwemt', 'Beweegt')}, 'subClassOf': {('Vis', 'Zwemmer'), ('Vis', 'Dier'), ('Vis', 'Blubblub'), ('Alleen', 'Eenzaam')}, 'domain': {('Zwemt', 'In_water')}, 'range': set()}, {('nemo', 'isa', 'Blubblub')}, {('Vis', 'isa', 'Zwemmen')})
# Triples:  ('nemo', 'Zwemt', 'Eenzaam')
# Triples:  ('nemo', 'isa', 'Dier')
# Triples:  ('nemo', 'Beweegt', 'Alleen')
# Triples:  ('nemo', 'isa', 'Vis')
# Triples:  ('nemo', 'isa', 'Zwemmer')
# Triples:  ('nemo', 'Beweegt', 'Eenzaam')
# Triples:  ('nemo', 'isa', 'Blubblub')
# Triples:  ('nemo', 'isa', 'In_water')
# Triples:  ('nemo', 'Zwemt', 'Alleen')
# ({('peter', 'isa', 'Duif'), ('peter', 'Vliegt_in', 'Lucht')}, {'subPropertyOf': {('Vliegt_in', 'Beweegt_in')}, 'subClassOf': {('Vogel', 'Heeft_Veren'), ('Vogel', 'Dier'), ('Vogel', 'Kan_Vliegen'), ('Dier', 'Organisme'), ('Lucht', 'The_Universe'), ('Duif', 'Vogel'), ('Organisme', 'Bestaat')}, 'domain': set(), 'range': set()}, {('peter', 'isa', 'Organisme')}, {('peter', 'isa', 'Kip')})
# Triples:  ('peter', 'Beweegt_in', 'The_Universe')
# Triples:  ('peter', 'isa', 'Vogel')
# Triples:  ('peter', 'isa', 'Bestaat')
# Triples:  ('peter', 'Vliegt_in', 'The_Universe')
# Triples:  ('peter', 'Beweegt_in', 'Lucht')
# Triples:  ('peter', 'isa', 'Duif')
# Triples:  ('peter', 'isa', 'Heeft_Veren')
# Triples:  ('peter', 'isa', 'Dier')
# Triples:  ('peter', 'Vliegt_in', 'Lucht')
# Triples:  ('peter', 'isa', 'Kan_Vliegen')
# Triples:  ('peter', 'isa', 'Organisme')
# ({('bugs_Bunny', 'isa', 'Konijn'), ('bugs_Bunny', 'Pleegt_Een', 'Overval')}, {'subPropertyOf': set(), 'subClassOf': {('Zoogdier', 'Dier'), ('Overval', 'Misdaad'), ('Dier', 'Organisme'), ('Knaagdier', 'Zoogdier'), ('Konijn', 'Knaagdier')}, 'domain': set(), 'range': set()}, {('bugs_Bunny', 'Pleegt_Een', 'Misdaad')}, {('bugs_Bunny', 'Pleegt_Een', 'Konijn')})
# Triples:  ('bugs_Bunny', 'isa', 'Konijn')
# Triples:  ('bugs_Bunny', 'isa', 'Dier')
# Triples:  ('bugs_Bunny', 'Pleegt_Een', 'Overval')
# Triples:  ('bugs_Bunny', 'isa', 'Knaagdier')
# Triples:  ('bugs_Bunny', 'isa', 'Organisme')
# Triples:  ('bugs_Bunny', 'Pleegt_Een', 'Misdaad')
# Triples:  ('bugs_Bunny', 'isa', 'Zoogdier')
# ({('beatrix', 'Drinkt', 'Wijn'), ('beatrix', 'isa', 'Elitaire_vrouw'), ('beatrix', 'Was', 'Koningin')}, {'subPropertyOf': {('Drinkt', 'Neemt_in')}, 'subClassOf': {('Vrouw', 'Mens'), ('Elitaire_vrouw', 'Vet_Gaaf_Persoon'), ('Mens', 'Sterfelijk')}, 'domain': {('Drinkt', 'Organisme')}, 'range': {('Drinkt', 'Drank')}}, {('beatrix', 'Drinkt', 'Drank')}, {('beatrix', 'isa', 'Koningin')})
# Triples:  ('beatrix', 'Drinkt', 'Drank')
# Triples:  ('beatrix', 'isa', 'Organisme')
# Triples:  ('beatrix', 'isa', 'Elitaire_vrouw')
# Triples:  ('beatrix', 'Was', 'Koningin')
# Triples:  ('beatrix', 'isa', 'Vet_Gaaf_Persoon')
# Triples:  ('beatrix', 'Neemt_in', 'Drank')
# Triples:  ('beatrix', 'Neemt_in', 'Wijn')
# Triples:  ('beatrix', 'Drinkt', 'Wijn')
# ({('günter', 'Isst', 'Sauerkraut'), ('mohamed', 'Eet', 'Baklava'), ('elena', 'Mag_Geen', 'Wasmachine'), ('eva', 'Houdt_van', 'Donkerbruine_Mannen')}, {'subPropertyOf': {('Eet', 'Vindt_lekker')}, 'subClassOf': {('Donkerbruine_Mannen', 'Afro_Amerikanen'), ('Wasmachine', 'Apparaat')}, 'domain': {('Houdt_van', 'Mens')}, 'range': {('Isst', 'Voedsel'), ('Eet', 'Voedsel')}}, {('mohamed', 'Vindt_lekker', 'Baklava')}, {('mohamed', 'Houdt_van', 'eva')})
# Triples:  ('günter', 'Isst', 'Sauerkraut')
# Triples:  ('mohamed', 'Vindt_lekker', 'Voedsel')
# Triples:  ('mohamed', 'Eet', 'Voedsel')
# Triples:  ('eva', 'Houdt_van', 'Afro_Amerikanen')
# Triples:  ('mohamed', 'Vindt_lekker', 'Baklava')
# Triples:  ('mohamed', 'Eet', 'Baklava')
# Triples:  ('günter', 'Isst', 'Voedsel')
# Triples:  ('elena', 'Mag_Geen', 'Wasmachine')
# Triples:  ('eva', 'Houdt_van', 'Donkerbruine_Mannen')
# Triples:  ('eva', 'isa', 'Mens')
# Triples:  ('elena', 'Mag_Geen', 'Apparaat')
# ({('patrick', 'Houdt_Van', 'Spons'), ('spongebob', 'isa', 'Spons'), ('patrick', 'isa', 'Zeester')}, {'subPropertyOf': set(), 'subClassOf': {('Zeester', 'Zeedieren'), ('Spons', 'Zeedieren')}, 'domain': {('Houdt_van', 'Organisme')}, 'range': set()}, {('patrick', 'isa', 'Zeedieren')}, {('spongebob', 'isa', 'Zeester')})
# Triples:  ('patrick', 'Houdt_Van', 'Spons')
# Triples:  ('spongebob', 'isa', 'Zeedieren')
# Triples:  ('patrick', 'isa', 'Zeester')
# Triples:  ('patrick', 'Houdt_Van', 'Zeedieren')
# Triples:  ('patrick', 'isa', 'Zeedieren')
# Triples:  ('spongebob', 'isa', 'Spons')

# %%
assert isinstance(testnaam,list)
for test in testnaam:
    assert isinstance(test,tuple)
    assert len(test)==4
    assert isinstance(test[0],set)
    assert isinstance(test[1],dict)
    assert isinstance(test[2],set)
    assert isinstance(test[3],set)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-500b0aa181b3> in <module>
# ----> 1 assert isinstance(testnaam,list)
#       2 for test in testnaam:
#       3     assert isinstance(test,tuple)
#       4     assert len(test)==4
#       5     assert isinstance(test[0],set)
#
# AssertionError:

# %% [markdown]
# # Voor de echte diehards die gaan voor een 10
#
# Franconi beschrijft in zijn artikel dat je ook RDFS statements uit andere RDFS statements kunt afleiden. Hij geeft een leuk voorbeeld in het eerste plaatje.
#
# Dat kan jij natuurlijk ook!
#
# Maak een functie `complete(RDFS)` die precies alle RDFS statements afleidt die volgen uit de verzameling `RDFS`.
#
# Maak er ook weer een mooie testset bij, en beargumenteer dat jouw systeem geldig en volledig is.
#
# ### Hoeveel RDFS statements zijn er eigenlijk die zouden kunnen volgen?
#
# * Gegeven de relaties en eigenschappen in de verzameling `RDFS` is dit eindig.
# * En er zijn maar 4 soorten RDFS statements.
# * Dus moet het wel eindig zijn, en kan je zelfs uitrekenen hoeveel.
# * Een manier is om ze allemaal te proberen....
#     * Voeg het antecedent toe als RDF-triple aan `RDFS` en kijk of het consequent dan volgt...
# * Reken het eens uit voor $r$ relaties en $p$ eigenschappen.
#     * Met $r$ relaties kan je $r\cdot(r-1)$ veel `subPropertyOf` relaties maken toch...
#     * en dan nog ....
#     * en ....
# * Dit is niet eens zo gek, maar met een *chase* gaat het natuurlijk veel sneller omdat je dan resultaatgericht werkt in plaats van als een dolle alles gaat proberen.
#     * Bijv; Stel je hebt 100 relaties, maar in je RDFS komt er maar 1 voor in antecdent positie in `subPropertyOf` statements. Hoeveel `subPropertyOf` kan je dan afleiden? Ja, dat is dus sneller dan al die 100*99 te gaan proberen toch? Want dat is best veel.
