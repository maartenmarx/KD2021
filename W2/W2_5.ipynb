# %% [markdown]
# # Assignment Netwerkanalyse

# %% [markdown]
# ## Notebook made by
#
#
# |Naam| Studentnummer |
# | ------------------- | ------------- |
# |Nathan| secret      |
# |Noah| secret      |
# |Björn| secret      |
#
# ## Peerreview
#
# * Vul onderstaande dict/tabel in en run de cel. Klopt het? Zijn jullie het er allemaal mee eens?
#     * Verander `1,2,3,4` door jullie studentnummers
#     * `1: {1:.2,2:.3,3:.3,4:.2}` betekent dat student 1 zijn punt zo over de 4 studenten verdeelt
#     * Let op, per student moeten de punten optellen tot 1!
#     * De gegeven punten staan in de tabel op de rijen, de ontvangen punten in de kolommen.
#     * met `cijfer_per_student` kan je bepalen welk cijfer ieder krijgt bij een gegeven groepscijfer.

# %% [markdown]
# ## Toelichting
#
# * De meeste opgaven worden automatisch nagekeken. Bij vrijwel alle opdrachten staan er een paar tests onder de opdracht, dit is voornamelijk om te zorgen dat je de juiste type output geeft. Dit zijn dus *NIET* alle tests, die komen er bij het graden nog bij.
# * Elke vraag is 1 punt waard, tenzij anders aangegeven. Soms is die punt onderverdeeld in deelpunten, maar niet altijd.
#
# ## Voor het inleveren!
#
# * Pas niet de cellen aan, vooral niet die je niet kunt editen. Dit levert problemen op bij nakijken. Twijfel je of je per ongeluk iets hebt gewijzigd, kopieer dan bij inleveren je antwoorden naar een nieuw bestand, zodat het niet fout kan gaan.
#
# * Zorg dat de code goed runt van boven naar beneden, verifieer dat door boven in Kernel -> Restart & Run All uit te voeren
#
# ## Na het inleveren!
#
# * Het gebeurt erg vaak dat mensen een "leeg bestand" inleveren. Vaak een andere versie van de opgave die nog ergens op je computer rondslingerde. Zonde van al je werk toch!
# * Dus, lever **minstens een half uur voor tijd in**. Download dan wat je hebt ingeleverd op Canvas. Geef het een andere naam om verwarring te voorkomen. En draai alle cellen, en bekijk het. Geen syntax fouten? Alle vragen gemaakt? Dan zit het vast wel goed, en hoef je niet in de zenuwen te zitten.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Instructie" data-toc-modified-id="Instructie-1">Instructie</a></span></li><li><span><a href="#Definieer-familie-relaties-en-LHBTQI++" data-toc-modified-id="Definieer-familie-relaties-en-LHBTQI++-2">Definieer familie relaties en LHBTQI++</a></span><ul class="toc-item"><li><span><a href="#1-De-gebruikelijke-familierelaties" data-toc-modified-id="1-De-gebruikelijke-familierelaties-2.1">1 De gebruikelijke familierelaties</a></span><ul class="toc-item"><li><span><a href="#Jullie-opdracht" data-toc-modified-id="Jullie-opdracht-2.1.1">Jullie opdracht</a></span></li><li><span><a href="#Networkx" data-toc-modified-id="Networkx-2.1.2">Networkx</a></span></li></ul></li></ul></li><li><span><a href="#Uitwerking-van-opdracht-1" data-toc-modified-id="Uitwerking-van-opdracht-1-3">Uitwerking van opdracht 1</a></span></li><li><span><a href="#2-Definieer-LHBTQI+" data-toc-modified-id="2-Definieer-LHBTQI+-4">2 Definieer LHBTQI+</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Let-op!" data-toc-modified-id="Let-op!-4.0.1">Let op!</a></span></li></ul></li><li><span><a href="#Jullie-opdracht" data-toc-modified-id="Jullie-opdracht-4.1">Jullie opdracht</a></span></li></ul></li><li><span><a href="#Uitwerking-van-opdracht-2" data-toc-modified-id="Uitwerking-van-opdracht-2-5">Uitwerking van opdracht 2</a></span></li></ul></div>

# %% [markdown]
# # Instructie
#
# * 2 opdrachten, elke opdracht kent een Markdown (tekst) deel en een programmeer deel. Voor elk deel kan je 10 punten verdienen. In totaal zijn er dus 40 punten te verdienen.
# * Succes! Maak er wat moois van!
# * Let op, dit is een vrije opdracht, en er zijn dus meerdere antwoorden goed. Het belangrijkste is dat jullie er over praten, zowel in je groepje als daarbuiten. **Geef in je opdracht aan als je een speciale keuze hebt gemaakt, en geef dan ook de reden. Dat is veel leuker en beter dan dat te verzwijgen/verhullen. En levert je juist punten op.**

# %% [markdown]
# # Definieer familie relaties en LHBTQI++
#
# In deze opdracht gaan jullie relaties definieren in termen van meer primitieve relaties. Ook ga je beperkingen op je modellen aanbrengen waarvan je vindt dat die gelden in onze wereld. Zo zorg je ervoor dat elk model van jouw theorie zo goed mogelijk overeenkomt met onze wereld.
#
# ## 1 De gebruikelijke familierelaties
#
# * We werken met predicaatlogische modellen, en met een basistaal met 2 eigenschappen: $M$ en $V$, die staan voor de 2 traditionele geslachten, en 1 twee plaatsige relatie $R$, die staat voor *is ouder van*. Hieronder staat dus dat *piet een man is, en joke een vrouw en dat piet de ouder is van joke*:
#
# $$M(piet), V(joke), R(piet,joke).$$
# * Wij gaan nu 2 dingen doen:
#     1. beperkingen opleggen aan de relaties
#     2. nieuwe relaties definieren in termen van de 3 primtieve relaties $M,V,R$
#         * in die nieuwe relaties kan je natuurlijk andere eerder gedefinieerde relaties weer gebruiken.
# * **Voorbeelden**
# * *Beperking:*
#     * Iedereen is man of vrouw (en nooit allebei tegelijk).
#     * Iedereen heeft exact 2 ouders, een man en een vrouw.
# * *Nieuwe relatie*
#     * $Vader(x,y)$ precies dan en slechts dan alleen als x een ouder is van y en x een man is.
#         * $\forall xy( Vader(x,y) \leftrightarrow R(x,y) \wedge M(x))$
#     * $Opa(x,y)$ hiervoor gebruik je natuurlijk het $\exists z$    connectief.
#         * Je kunt dit netjes definieren in termen van ouder en vader.
#
# ### Jullie opdracht
#
# 1. Definieer een flink aantal familierelaties.
# 2. Verzin minstens 1 bestaande familierelatie die je **niet in predicaatlogica** kunt definieren.
#     * Leg uit wat er lastig/bijzonder aan is.
# 3. Geef een aantal beperkingen die (mogelijk) waar zouden kunnen zijn in de echte wereld.
#     * Ik schrijf mogelijk omdat het voorbeeld hierboven dat iedereen precies 2 ouders heeft natuurlijk ook omstreden is. Dat geeft niet, je geeft dat dan gewoon aan.
#     * Beschrijf de beperking eerst in heel helder Nederlands, en geef daarnaast de exacte logische zin die erbij past.
#     * Op $R$ kan je natuurlijk al heel wat beperkingen opleggen:
#         * niemand is ouder van zichzelf
#         * ouder is asymmetrisch
#         * ....
#
# ### Networkx
#
# * Maak nu een model van je eigen familie in networkx.
# * Stop er minstens 50 mensen in (uit je hele groepje), geef ze allemaal een geslacht en leg de juiste relaties.
# * Maak een mooi plaatje.
# * Definieer met comprehensies alle relaties die je boven ook gedefinieerd hebt.
#     * Maak ook een plaatje, en check dat het klopt.
# * Zorg dat het er zo netjes en helder uitziet    dat je echt snel en makkelijk kunt checken dat het klopt.
#     * Dit zijn dingen die voor zichzelf spreken: zorg dus ook dat het in jullie opdract zo is.

# %%
import networkx as nx
# %matplotlib inline

# %%
# Voorbeeld om je op weg te helpen


H= nx.house_graph()  # In het echt neem je natuurlijk een nx.Digraph !
H[1]
nx.draw_networkx(H)
M,V= {1,3,0},{2,4} # de mannen en de vrouwen in dit netwerk
# Nu even de attributen M en V goed zetten
for n in M:
    H.nodes[n]['M']=True
    H.nodes[n]['V']=False
for n in V:
    H.nodes[n]['V']=True
    H.nodes[n]['M']=False    
 

# wat handige afkortingen om de comprehensies zo veel mogelijk op je formules te laten lijken
G=H
def M(x, network=G):
    return network.nodes[x]['M']
def V(x, network=G):
    return network.nodes[x]['V']
def R(x,y,network=G):
    return network.has_edge(x,y)

# Vader(x,y) iff R(x,y) & M(x)
# Bijna hetzelfde als in deze comprehensie toch?
Vader= {(x,y) for x in H for y in H if R(x,y,H) and M(x,H)}
print(Vader)
# Out:
# {(0, 1), (3, 4), (3, 1), (0, 2), (1, 0), (3, 2), (1, 3)}

# %%
# Dit kan in het echt natuurlijk niet!

Va = nx.DiGraph()
Va.add_edges_from(Vader)
nx.draw_kamada_kawai(Va)

# %%
# Voorbeeld met een existentiele quantifier
# Kan ook anders hoor.

H= nx.DiGraph()
H.add_edges_from([(0,1), (1,2), (1,4), (2,3)])


# Opa(x,y) iff M(x) & \exists z (R(x,z) & R(z,y) )
# hier laat ik de M(x) even weg
Opa= {(x,y) for x in H for y in H 
      if {z for z in H if R(x,z,H)} & {z for z in H if R(z,y,H)}}
Opa
# Out:
# {(0, 2), (0, 4), (1, 3)}

# %% [markdown]
# # Uitwerking van opdracht 1
#
# * eerst in Markdown en Latex
# * dan een blok in code

# %% [markdown]
# ## Familierelaties
# ### Ouder
# $R(x,y)$: $x$ is de ouder van $y$
#
# ### Vader
# Iemands vader is diens mannelijke ouder.<br>
#
# $x$ is de vader van $y$ precies dan en slechts dan alleen als $x$ de ouder is van $y$ **EN** $x$ mannelijk is.<br>
#
# $\forall xy(Vader(x,y) \leftrightarrow R(x,y) \wedge M(x))$
#
# ### Moeder
# Iemands moeder is diens vrouwelijke ouder.<br>
#
# $x$ is de moeder van $y$ precies dan en slechts dan alleen als $x$ de ouder is van $y$ **EN** $x$ vrouwelijk is.<br>
#
# $\forall xy(Moeder(x,y) \leftrightarrow R(x,y) \wedge V(x))$
#
# ### Zoon
# Iemands zoon is diens mannelijke kind.<br>
#
# $x$ is de zoon van $y$ precies dan en slechts dan alleen als $y$ de ouder is van $x$ **EN** $x$ mannelijk is.<br>
#
# $\forall xy(Moeder(x,y) \leftrightarrow R(y,x) \wedge M(x))$
#
# ### Dochter
# Iemands dochter is diens vrouwelijke kind.<br>
#
# $x$ is de dochter van $y$ precies dan en slechts dan alleen als $y$ de ouder is van $x$ **EN** $x$ vrouwelijk is.<br>
#
# $\forall xy(Moeder(x,y) \leftrightarrow R(y,x) \wedge V(x))$
#
# ### Broer of zus
# Iemands broer of zus is iemand anders met minstens één dezelfde ouder.
#
# $x$ is de broer of zus van $y$ precies dan en slechts dan alleen als er een $z$ bestaat waarvoor geldt dat $z$ de ouder is van $x$ **EN** $z$ de ouder is van $y$, **EN** $x$ en $y$ niet dezelfde persoon zijn.<br>
#
# $\forall xy(Broerofzus(x,y) \leftrightarrow \exists z(R(z,x) \wedge R(z,y)) \wedge \neg(x = y))$
#
# ### Broer
# Iemands broer is een ander mannelijk persoon met minstens één dezelfde ouder.
#
# $x$ is de broer van $y$ precies dan en slechts dan alleen als er een $z$ bestaat waarvoor geldt dat $z$ de ouder is van $x$ **EN** $z$ de ouder is van van $y$, **EN** $x$ mannelijk is **EN** $x$ en $y$ niet dezelfde persoon zijn.<br>
#
# $\forall xy(Broer(x,y) \leftrightarrow \exists z(R(z,x) \wedge R(z,y)) \wedge M(x) \wedge \neg(x = y))$
#
# ### Zus
# Iemands zus is een ander vrouwelijk persoon met minstens één dezelfde ouder.
#
# $x$ is de zus van $y$ precies dan en slechts dan alleen als er een $z$ bestaat waarvoor geldt dat $z$ de ouder is van $x$ **EN** $z$ de ouder is van van $y$, **EN** $x$ vrouwelijk is **EN** $x$ en $y$ niet dezelfde persoon zijn.<br>
#
# $\forall xy(Zus(x,y) \leftrightarrow \exists z(R(z,x) \wedge R(z,y)) \wedge V(x) \wedge \neg(x = y))$
#
# ### Grootouder
# De ouders van iemands ouders zijn diegene's grootouders.
#
# $x$ is de grootouder van $y$ precies dan en slechts dan alleen als er een $z$ bestaat waarvoor geldt dat $x$ de ouder is van $z$ **EN** $z$ de ouder is van $y$.<br>
#
# $\forall xy(Grootouder(x,y) \leftrightarrow \exists z(R(x,z) \wedge R(z,y)))$
#
# ### Oma
# De moeders van iemands ouders zijn diegene's oma's.<br>
#
# $x$ is de oma van $y$ precies dan en slechts dan alleen als er een $z$ bestaat waarvoor geldt dat $x$ de moeder is van $z$ **EN** $z$ de ouder is van $y$.<br>
#
# $\forall xy(Oma(x,y) \leftrightarrow \exists z(Moeder(x,z) \wedge R(z,y)))$
#
# ### Opa
# De vaders van iemands ouders zijn diegene's opa's.<br>
#
# $x$ is de opa van $y$ precies dan en slechts dan alleen als er een $z$ bestaat waarvoor geldt dat $x$ de vader is van $z$ **EN** $z$ de ouder is van $y$.<br>
#
# $\forall xy(Opa(x,y) \leftrightarrow \exists z(Vader(x,z) \wedge R(z,y)))$
#
# ### Oom of tante
# De broers en zussen van iemands ouders zijn diegene's ooms of tantes. **N.B.:** De echtgenoten van de broers of zusssen van diens ouders tellen niet mee.
#
# $x$ is de oom of tante van $y$ precies dan en slechts alleen als er een $z$ bestaat waarvoor geldt dat $z$ een ouder is van $y$ **EN** $x$ een broer of zus is van $z$.<br>
#
# $\forall xy(Oomoftante(x,y) \leftrightarrow \exists z(R(z,y) \wedge Broerofzus(x,z)))$
#
# ### Oom
# Iemands ooms zijn de broers van diegene's ouders.<br>
#
# $x$ is de oom van $y$ precies dan en slechts alleen als $x$ de oom of tante is van $y$ **EN** $x$ mannelijk is.<br>
#
# $\forall xy(Oom(x,y) \leftrightarrow Oomoftante(x,y) \wedge M(x))$
#
# ### Tante
# Iemands tantes zijn de zussen van diegene's ouders.<br>
#
# $x$ is de tante van $y$ precies dan en slechts alleen als $x$ de oom of tante is van $y$ **EN** $x$ vrouwelijk is.<br>
#
# $\forall xy(Tante(x,y) \leftrightarrow Oomoftante(x,y) \wedge V(x))$
#
# ### Nicht
# Je bent iemands nicht als je:
# 1. dochter bent van diens oom of tante; of
# 2. dochter bent van diens broer of zus. <br>
#
# $x$ is de nicht van $y$ precies dan en slechts dan alleen als er een $z$ bestaat waarvoor geldt dat
# $x$ de dochter is van $z$ **EN** $z$ de broer of zus is van $y$, **OF** als er een $z$ bestaat waarvoor geldt dat $x$ de dochter is van $z$ **EN** $z$ de oom of tante is van $y$.<br>
#
# $\forall xy(Nicht(x,y) \leftrightarrow \exists z(Dochter(x,z) \wedge Broerofzus(z,y)) \vee \exists z(Dochter(x,z) \wedge Oomoftante(z,y)))$
#
# ### Neef
# Je bent iemands neef als je:
# 1. zoon bent van diens oom of tante; of
# 2. zoon bent van diens broer of zus. <br>
#
# $x$ is de neef van $y$ precies dan en slechts dan alleen als er een $z$ bestaat waarvoor geldt dat
# $x$ de zoon is van $z$ **EN** $z$ de broer of zus is van $y$, **OF** als er een $z$ bestaat waarvoor geldt dat $x$ de zoon is van $z$ **EN** $z$ de oom of tante is van $y$.<br>
#
# $\forall xy(Neef(x,y) \leftrightarrow \exists z(Zoon(x,z) \wedge Broerofzus(z,y)) \vee \exists z(Zoon(x,z) \wedge Oomoftante(z,y)))$
#
# ### Achterneef
# Wij definiëren achterneef alleen als een zoon van een neef of nicht en NIET als een zoon van een oudoom of oudtante.
#
# $x$ is de achterneef van $y$ precies dan en slechts dan alleen als er een $z$ bestaat waarvoor geldt dat $x$ de zoon is van $z$ **EN** $z$ de neef is van $y$ **OF** $z$ de nicht is van $y$.<br>
#
# $\forall xy(Achterneef(x,y) \leftrightarrow \exists z(Zoon(x,z) \wedge (Nicht(z,y) \vee Neef(z,y)))$
#
# ### Achternicht
# Wij definiëren achternicht alleen als een dochter van een neef of nicht en NIET als een dochter van een oudoom of oudtante.
#
# $x$ is de achternicht van $y$ precies dan en slechts dan alleen als er een $z$ bestaat waarvoor geldt dat $x$ de dochter is van $z$ **EN** $z$ de neef is van $y$ **OF** $z$ de nicht is van $y$.<br>
#
# $\forall xy(Achternicht(x,y) \leftrightarrow \exists z(Dochter(x,z) \wedge (Nicht(z,y) \vee Neef(z,y)))$
#
# ## Beperkingen
# - Niemand is ouder van zichzelf: $\forall x(\neg R(x,x))$
# - Niemand is ouder van zijn of haar eigen ouder: $\forall xy(R(x,y) \rightarrow \neg R(y,x))$
# - Iedereen is man of vrouw, en nooit beiden tegelijk: $\forall x(M(x) \veebar V(x))$
#   - N.B.: Dit is, uiteraard, omstreden. Dit is echter een noodzakelijke beperking voor deze opdracht om de relaties enigszins redelijk te kunnen definiëren.
# - Niemand is zowel vader als moeder: $\forall x(\exists y(Vader(x,y)) \leftrightarrow \neg \exists y(Moeder(x,y)))$
# - Iedereen die een broer of zus heeft is ook de broer of zus van die persoon: $\forall xy(Broerofzus(x,y) \leftrightarrow Broerofzus(y,x))$
# - Niemand is de ouder van zijn of haar broer of zus: $\forall xy(R(x,y) \rightarrow \neg Broerofzus(x,y))$
#
# ## Familierelaties die we niet kunnen uitdrukken in predicaatlogica
# ### Aangetrouwde familie & eigen partner
# Want de relatie 'partner van' is geen ding in dit universum. Wij beperken ons tot het universum van $M(x)$, $V(x)$ en $R(x,y)$ waarbij $R$ een ouderrelatie betekent. Er is dus niet zoiets als aangetrouwde familie en dus ook geen eigen partner van $x$.
#
# ### Stiefbroer/stiefzus
# Hier hetzelfde probleem, aangezien het niet mogelijk is partners (en dus ook niet 'voormalige partners') uit te drukken. Er is dus geen mogelijkheid de band met de aangetrouwde kinderen van een van de ouders van $x$ uit te drukken. Noemenswaardig is wel dat halfbroers en halfzussen wel kunnen, en die vallen ook in onze hierboven gestelde definitie van broer of zus. Dit komt omdat halfbroers en halfzussen wel een ouder delen.

# %%
from networkx.drawing.nx_agraph import write_dot, graphviz_layout
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['figure.figsize'] = (12,8)

G = nx.DiGraph()
Ma,Vr= {"Harry","Bob","Noah","Nikolai",
      "Nick","Stijn","Senne","Milan", 
      "Melvin","Andre","Hans","Ruud", 
      "Barry", "Tjibbe", "Theo", "Fred", 
      "Sem", "Liam", "Lucas", "Daan", 
      "Finn", "Luuk", "Mees", "Opa", 
      "James", "Jasper", "Levi"},{"Janneke", 
      "Marieke", "Kitty","Sandra",
      "Jettie", "Stefanie","Ilse",
      "Janneke2","Sterre","Juultje",
      "Sandra2","Julia","OmaRijks", 
      "Emma", "Julia2", "Mila", 
      "Tess", "Sophie", "Zoe", 
      "Sara", "Nora", "Yara", 
      "Eva", "Liv"}

relations = [("OmaRijks","Harry"),("OmaRijks","Kitty"),("OmaRijks","Janneke"),("OmaRijks","Sandra"),("OmaRijks","Juultje"),
            ("OmaRijks","Jettie"),("OmaRijks","Ilse"),("Opa","Harry"),("Opa","Kitty"),("Opa","Janneke"),("Opa","Sandra"),
            ("Opa","Juultje"),("Opa","Jettie"),("Opa","Ilse"),("Kitty","Nick"),("Janneke","Marieke"),("Janneke","Bob"),
            ("Marieke","Noah"),("Marieke","Nikolai"),("Sandra","Stijn"),("Juultje","Sandra2"),("Sandra2","Milan"),
            ("Sandra2","Julia"),("Jettie","Stefanie"),("Jettie","Melvin"),("Stefanie","Senne"),("Ilse","Janneke2"),
            ("Janneke2","Sterre"),("Kitty","Nick"),("Andre","Stijn"),("Hans","Nick"),("Ruud","Marieke"),("Ruud","Bob"),
            ("Barry","Senne"), ("Ilse","Tjibbe"), ("Theo","Janneke2"), ("Theo","Tjibbe"),("Fred","Sandra2"),
            ("Noah","Sem"),("Noah","Liam"),("Noah","Emma"),("Nikolai","Julia2"),("Nikolai","Mila"),("Stijn","Lucas"),
            ("Stijn","Daan"),("Stijn","Tess"),("Nick","Sophie"),("Nick","Zoe"),("Senne","Sara"),("Senne","Finn"),
            ("Senne","Levi"),("Melvin","Luuk"),("Melvin","Mees"),("Bob","James"),("Bob","Jasper"),("Harry","Nora"),
            ("Harry","Yara"),("Milan","Eva"),("Milan","Liv")]


G.add_nodes_from(Ma)
G.add_nodes_from(Vr)

G.add_edges_from(relations, color='black',weight=2)

for n in Ma:
    G.nodes[n]['M']=True
    G.nodes[n]['V']=False
for n in Vr:
    G.nodes[n]['V']=True
    G.nodes[n]['M']=False
        
color_map = [('#ff9b94' if G.nodes[node]['V'] else '#a9afe8') for node in G]
    

pos = graphviz_layout(G, prog='dot')

nx.draw(G, pos, node_color=color_map, with_labels=False, arrows=True)
plt.title('Ouders')

plt.show()

vader = {(x,y) for x in G for y in G if R(x,y,G) and M(x,G)}
moeder = {(x,y) for x in G for y in G if R(x,y,G) and V(x,G)}
zoon = {(x,y) for x in G for y in G if R(y,x,G) and M(x,G)}
dochter = {(x,y) for x in G for y in G if R(y,x,G) and V(x,G)}
broerofzus = {(x,y) for x in G for y in G if {z for z in G if R(z,x,G) and R(z,y,G)} and x!=y}
broer = {(x,y) for x in G for y in G if {z for z in G if R(z,x,G) and R(z,y,G)} and M(x,G) and x!=y}
zus = {(x,y) for x in G for y in G if {z for z in G if R(z,x,G) and R(z,y,G)} and V(x,G) and x!=y}

Moeder = lambda x,y: (x,y) in moeder
Vader = lambda x,y: (x,y) in vader
Broerofzus = lambda x,y: (x,y) in broerofzus
Zoon = lambda x,y: (x,y) in zoon
Dochter = lambda x,y: (x,y) in dochter

grootouder = {(x,y) for x in G for y in G if {z for z in G if R(x,z,G) and R(z,y,G)}}
oma = {(x,y) for x in G for y in G if {z for z in G if Moeder(x,z) and R(z,y,G)}}
opa = {(x,y) for x in G for y in G if {z for z in G if Vader(x,z) and R(z,y,G)}}
oomoftante = {(x,y) for x in G for y in G if {z for z in G if R(z,y,G) and Broerofzus(x,z)}}

Oomoftante = lambda x,y: (x,y) in oomoftante

oom = {(x,y) for x in G for y in G if Oomoftante(x,y) and M(x,G)}
tante = {(x,y) for x in G for y in G if Oomoftante(x,y) and V(x,G)}
nicht = {(x,y) for x in G for y in G if {z for z in G if Dochter(x,z) and Broerofzus(z,y)} or {z for z in G if Dochter(x,z) and Oomoftante(z,y)}}
neef = {(x,y) for x in G for y in G if {z for z in G if Zoon(x,z) and Broerofzus(z,y)} or {z for z in G if Zoon(x,z) and Oomoftante(z,y)}}

Neef = lambda x,y: (x,y) in neef
Nicht = lambda x,y: (x,y) in nicht

achterneef = {(x,y) for x in G for y in G if {z for z in G if Zoon(x,z) and (Nicht(z,y) or Neef(z,y))}}
achternicht = {(x,y) for x in G for y in G if {z for z in G if Dochter(x,z) and (Nicht(z,y) or Neef(z,y))}}







##########################################################################################################
#
# LET OP: vervang 'Broer' in de regel hieronder gerust voor welke andere comprehension dan ook.
# Iedere comprehension kan op deze manier gevisualiseerd worden.
#
##########################################################################################################

Welkerelatie = broer







G.add_edges_from(Welkerelatie, color='green',weight=1)

colors = [G[u][v]['color'] for u,v in G.edges]
weights = [G[u][v]['weight'] for u,v in G.edges]

nx.draw(G, pos, node_color=color_map, with_labels=False, arrows=True, edge_color=colors, width=weights)
plt.title('Ouders (zwart) + gekozen comprehensie (groen)')

plt.show()

# %% [markdown]
# # 2 Definieer LHBTQI+
#
# * OK, ga er maar aan staan. Linda probeert het op <https://www.linda.nl/nieuws/we-leggen-het-gewoon-uit-waar-staat-lhbtqi-voor/>.
# * Nu is het jullie beurt.
# * Dus neem wat primitieven, maar zo min mogelijk,
#     * Man, Vrouw, en allicht nog iets, plus logische relaties daartussen
#     * een binaire relatie $R$ die "liefdes-relaties" aangeeft...
#         * Jij geeft heel exact aan wat $R(x,y)$ voor jullie betekent
#     * misschien nog 1 of 2 andere primitieven
#         * Geef heel exact aan wat ze betekenen
#
# ### Let op!
#
# * Vergelijk deze 3 (echt niet equivalente) definities:
#     * Je bent een hetero als je van iemand houdt van het andere geslacht
#     * ... als je alleen maar van mensen houdt van het andere geslacht
#     * ... als je van iemand houdt van het andere geslacht **en** als je alleen maar van mensen houdt van het andere geslacht
#     * eeh, *het* andere geslacht..., is er maar 1 dan?
# * Je merkt het, je moet heel precies zijn!
# * Deze opdracht is alleen goed te doen, als jullie elkaar steeds controleren en scherp houden, en opjutten om precies te zijn of worden of blijven.
# * Maak ook steeds heldere voorbeelden/modellen, en kijk wat je definities doen op die modellen.
#
# ## Jullie opdracht
#
# * Maak net als boven een theorie voor je primitieven, en definieer alle letters (plus wat er onder de + valt) in termen van je primitieven
# * Als het echt niet lukt of kan, zal je dat echt helder moeten motiveren.
# * Maak een networkx model met van elke LHBTQI+ letter minstens 1 knoop die zo is volgens jouw definitie.
# * Geef exact aan, of mensen meerdere letters tegelijk kunnen zijn,
#     * Is iedereen nou 1 van deze letters, of zijn er ook nog andere categorieen? Welke dan? Kan je die ook definieren?

# %% [markdown]
# # Uitwerking van opdracht 2

# %% [markdown]
# ## Primitieven
# $M(x)$ betekent dat $x$ zich identificeert als een man <br>
# $V(x)$ betekent dat $x$ zich identificeert als een vrouw <br>
# $MG(x)$ betekent dat $x$ geboren is met mannelijke geslachtseigenschappen <br>
# $VG(x)$ betekent dat $x$ geboren is met vrouwelijke geslachtseigenschappen <br>
#
# $R(x,y)$ betekent dat $x$ zich romantische of seksueel aangetrokken voelt tot $y$
#
# ## Letters
# ### Heteroseksueel
# Iemand is heteroseksueel wanneer deze persoon zich aangetrokken voelt tot iemand en zich tot niemand aangetrokken voelt die zich met hetzelfde geslacht identificeert.
#
# $\forall x(Heteroseksueel(x) \leftrightarrow \exists y(R(x,y)) \wedge ((M(x) \wedge \neg \exists y(R(x,y) \wedge M(y))) \vee (V(x) \wedge \neg \exists y(R(x,y) \wedge V(y)))))$
#
# ### Homoseksueel
# Iemand is homoseksueel wanneer deze persoon zich identificeert als man, hij zich aangetrokken voelt tot minstens één persoon en hij zich tot niemand aangetrokken voelt die zich identificeert als vrouw.
#
# $\forall x(Homoseksueel(x) \leftrightarrow M(x) \wedge \exists y(R(x,y)) \wedge \neg \exists y(V(y) \wedge R(x,y)))$
#
# ### Lesbisch
# Iemand is lesbisch wanneer deze persoon zich identificeert als vrouw, zij zich aangetrokken voelt tot minstens één persoon en zij zich tot niemand aangetrokken voelt die zich identificeert als man.
#
# $\forall x(Lesbisch(x) \leftrightarrow V(x) \wedge \exists y(R(x,y)) \wedge \neg \exists y(M(y) \wedge R(x,y)))$
#
# ### Biseksueel
# Iemand is biseksueel wanneer deze persoon zich aangetrokken voelt tot minstens één persoon die zich als man identificeert en één persoon die zich als vrouw identificeert. **N.B.:** Hierbij maken wij duidelijk onderscheid tussen biseksualiteit en panseksualiteit, oftewel het vallen op een mens ongeacht de persoon hun sekse of genderidentiteit.<br>
#
# $\forall x(Biseksueel(x) \leftrightarrow \exists y(R(x,y) \wedge M(y)) \wedge \exists y(R(x,y) \wedge V(y)))$
#
# ### Transgender
# Iemand is transgender wanneer hij zich identificeert als man maar geboren is zonder mannelijke geslachtseigenschappen en met vrouwelijke geslachtseigenschappen, of zij zich identificeert als vrouw maar geboren is zonder vrouwelijke geslachtseigenschappen en met mannelijke geslachtseigenschappen.
#
# $\forall x(Transgender(x) \leftrightarrow (M(x) \wedge \neg MG(x) \wedge VG(x)) \vee (V(x) \wedge \neg VG(x) \wedge MG(x)))$
#
# ### Queer / Questioning
# Iemand is queer/questioning wanneer deze persoon zich niet identificeert als man en zich ook niet identificeert als vrouw.
#
# $\forall x(Queer(x) \leftrightarrow \neg V(x) \wedge \neg M(x))$
#
# ### Interseksueel
# Iemand is interseksueel wanneer deze persoon zowel mannelijke als vrouwelijke geslachtseigenschappen heeft.
#
# $\forall x(Interseksueel(x) \leftrightarrow VG(x) \wedge MG(x))$
#
# ### +
# Wij houden voor de **+** aan dat deze persoon zich niet identificeert met de bovengenoemde termen voor seksuele orientatie en genderidenteit. <br>
# $\forall x(Plus(x) \leftrightarrow \neg Heteroseksueel(x) \wedge \neg Homoseksueel(x) \wedge \neg Lesbisch(x) \wedge \neg Biseksueel(x) \wedge \neg Transgender(x) \wedge \neg Queer(x) \wedge \neg Interseksueel(x))$
#
# ## Analyse
# Het is mogelijk dat één persoon onder meerdere van deze letters valt. Een persoon die zich identificeert als man, geboren is met uitsluitend vrouwelijke geslachtseigenschappen en uitsluitend valt op mensen die zich identificeren als mannen zou bijvoorbeeld onder de definities 'transgender' en 'homoseksueel' vallen.
#
# In principe kan niemand onder géén van deze categorieën vallen. De definitie van de plus is namelijk: iedereen die niet onder de eerder genoemde categorieën valt. Desondanks zijn er best nog meer categorieën te bedenken. Bijvoorbeeld:
#
# ### Aseksueel
# Iemand is aseksueel wanneer deze persoon zich tot niemand aangetrokken voelt.
#
# $\forall x(Aseksueel(x) \leftrightarrow \neg \exists y(R(x,y)))$

# %%
H = nx.DiGraph()
H.add_node(1, M=True, V=False, MG=True, VG=False, Groepen=['Homoseksueel'])
H.add_node(2, M=True, V=False, MG=True, VG=False, Groepen=['Biseksueel'])
H.add_node(3, M=False, V=True, MG=False, VG=True, Groepen=['Heteroseksueel'])
H.add_node(4, M=False, V=True, MG=False, VG=True, Groepen=['Lesbisch'])
H.add_node(5, M=False, V=True, MG=False, VG=True, Groepen=['+', 'Aseksueel'])
H.add_node(6, M=True, V=False, MG=False, VG=True, Groepen=['Transgender', 'Heteroseksueel'])
H.add_node(7, M=False, V=False, MG=False, VG=True, Groepen=['Queer'])
H.add_node(8, M=True, V=False, MG=True, VG=True, Groepen=['Interseksueel', 'Heteroseksueel'])
H.add_node(9, M=True, V=False, MG=True, VG=False, Groepen=['+'])

H.add_edges_from([(1,2), (2,1), (2,3), (3,2), (4,3), (6,3), (7,2), (8,4), (9,7)])

color_map = [('#ff9b94' if H.nodes[node]['V'] else ('#a9afe8' if H.nodes[node]['M'] else '#9fe880')) for node in H]

nx.draw(H, node_color=color_map, with_labels=True)
