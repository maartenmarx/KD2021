# %% [markdown]
# # Assignment Netwerkanalyse

# %% [markdown]
# ## Notebook made by
#
#
# |Naam|Studentnummer|
# |-|-|
# |Maarten| secret |
# |Jochem| secret |
# |Martijn| secret |
# |Martijn| secret |
#
# ## Peerreview
#
# * Vul onderstaande dict/tabel in en run de cel. Klopt het? Zijn jullie het er allemaal mee eens?
#     * Verander `1,2,3,4` door jullie studentnummers
#     * `1: {1:.2,2:.3,3:.3,4:.2}` betekent dat student 1 zijn punt zo over de 4 studenten verdeelt
#     * Let op, per student moeten de punten optellen tot 1!
#     * De gegeven punten staan in de tabel op de rijen, de ontvangen punten in de kolommen.
#     * met `cijfer_per_student` kan je bepalen welk cijfer ieder krijgt bij een gegeven groepscijfer.

# %% [markdown]
# ## Toelichting
#
# * De meeste opgaven worden automatisch nagekeken. Bij vrijwel alle opdrachten staan er een paar tests onder de opdracht, dit is voornamelijk om te zorgen dat je de juiste type output geeft. Dit zijn dus *NIET* alle tests, die komen er bij het graden nog bij.
# * Elke vraag is 1 punt waard, tenzij anders aangegeven. Soms is die punt onderverdeeld in deelpunten, maar niet altijd.
#
# ## Voor het inleveren!
#
# * Pas niet de cellen aan, vooral niet die je niet kunt editen. Dit levert problemen op bij nakijken. Twijfel je of je per ongeluk iets hebt gewijzigd, kopieer dan bij inleveren je antwoorden naar een nieuw bestand, zodat het niet fout kan gaan.
#
# * Zorg dat de code goed runt van boven naar beneden, verifieer dat door boven in Kernel -> Restart & Run All uit te voeren
#
# ## Na het inleveren!
#
# * Het gebeurt erg vaak dat mensen een "leeg bestand" inleveren. Vaak een andere versie van de opgave die nog ergens op je computer rondslingerde. Zonde van al je werk toch!
# * Dus, lever **minstens een half uur voor tijd in**. Download dan wat je hebt ingeleverd op Canvas. Geef het een andere naam om verwarring te voorkomen. En draai alle cellen, en bekijk het. Geen syntax fouten? Alle vragen gemaakt? Dan zit het vast wel goed, en hoef je niet in de zenuwen te zitten.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Instructie" data-toc-modified-id="Instructie-1">Instructie</a></span></li><li><span><a href="#Definieer-familie-relaties-en-LHBTQI++" data-toc-modified-id="Definieer-familie-relaties-en-LHBTQI++-2">Definieer familie relaties en LHBTQI++</a></span><ul class="toc-item"><li><span><a href="#1-De-gebruikelijke-familierelaties" data-toc-modified-id="1-De-gebruikelijke-familierelaties-2.1">1 De gebruikelijke familierelaties</a></span><ul class="toc-item"><li><span><a href="#Jullie-opdracht" data-toc-modified-id="Jullie-opdracht-2.1.1">Jullie opdracht</a></span></li><li><span><a href="#Networkx" data-toc-modified-id="Networkx-2.1.2">Networkx</a></span></li></ul></li></ul></li><li><span><a href="#Uitwerking-van-opdracht-1" data-toc-modified-id="Uitwerking-van-opdracht-1-3">Uitwerking van opdracht 1</a></span></li><li><span><a href="#2-Definieer-LHBTQI+" data-toc-modified-id="2-Definieer-LHBTQI+-4">2 Definieer LHBTQI+</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Let-op!" data-toc-modified-id="Let-op!-4.0.1">Let op!</a></span></li></ul></li><li><span><a href="#Jullie-opdracht" data-toc-modified-id="Jullie-opdracht-4.1">Jullie opdracht</a></span></li></ul></li><li><span><a href="#Uitwerking-van-opdracht-2" data-toc-modified-id="Uitwerking-van-opdracht-2-5">Uitwerking van opdracht 2</a></span></li></ul></div>

# %% [markdown]
# # Instructie
#
# * 2 opdrachten, elke opdracht kent een Markdown (tekst) deel en een programmeer deel. Voor elk deel kan je 10 punten verdienen. In totaal zijn er dus 40 punten te verdienen.
# * Succes! Maak er wat moois van!
# * Let op, dit is een vrije opdracht, en er zijn dus meerdere antwoorden goed. Het belangrijkste is dat jullie er over praten, zowel in je groepje als daarbuiten. **Geef in je opdracht aan als je een speciale keuze hebt gemaakt, en geef dan ook de reden. Dat is veel leuker en beter dan dat te verzwijgen/verhullen. En levert je juist punten op.**

# %% [markdown]
# # Definieer familie relaties en LHBTQI++
#
# In deze opdracht gaan jullie relaties definieren in termen van meer primitieve relaties. Ook ga je beperkingen op je modellen aanbrengen waarvan je vindt dat die gelden in onze wereld. Zo zorg je ervoor dat elk model van jouw theorie zo goed mogelijk overeenkomt met onze wereld.
#
# ## 1 De gebruikelijke familierelaties
#
# * We werken met predicaatlogische modellen, en met een basistaal met 2 eigenschappen: $M$ en $V$, die staan voor de 2 traditionele geslachten, en 1 twee plaatsige relatie $R$, die staat voor *is ouder van*. Hieronder staat dus dat *piet een man is, en joke een vrouw en dat piet de ouder is van joke*:
#
# $$M(piet), V(joke), R(piet,joke).$$
# * Wij gaan nu 2 dingen doen:
#     1. beperkingen opleggen aan de relaties
#     2. nieuwe relaties definieren in termen van de 3 primtieve relaties $M,V,R$
#         * in die nieuwe relaties kan je natuurlijk andere eerder gedefinieerde relaties weer gebruiken.
# * **Voorbeelden**
# * *Beperking:*
#     * Iedereen is man of vrouw (en nooit allebei tegelijk).
#     * Iedereen heeft exact 2 ouders, een man en een vrouw.
# * *Nieuwe relatie*
#     * $Vader(x,y)$ precies dan en slechts dan alleen als x een ouder is van y en x een man is.
#         * $\forall xy( Vader(x,y) \leftrightarrow R(x,y) \wedge M(x))$
#     * $Opa(x,y)$ hiervoor gebruik je natuurlijk het $\exists z$    connectief.
#         * Je kunt dit netjes definieren in termen van ouder en vader.
#
# ### Jullie opdracht
#
# 1. Definieer een flink aantal familierelaties.
# 2. Verzin minstens 1 bestaande familierelatie die je **niet in predicaatlogica** kunt definieren.
#     * Leg uit wat er lastig/bijzonder aan is.
# 3. Geef een aantal beperkingen die (mogelijk) waar zouden kunnen zijn in de echte wereld.
#     * Ik schrijf mogelijk omdat het voorbeeld hierboven dat iedereen precies 2 ouders heeft natuurlijk ook omstreden is. Dat geeft niet, je geeft dat dan gewoon aan.
#     * Beschrijf de beperking eerst in heel helder Nederlands, en geef daarnaast de exacte logische zin die erbij past.
#     * Op $R$ kan je natuurlijk al heel wat beperkingen opleggen:
#         * niemand is ouder van zichzelf
#         * ouder is asymmetrisch
#         * ....
#
# ### Networkx
#
# * Maak nu een model van je eigen familie in networkx.
# * Stop er minstens 50 mensen in (uit je hele groepje), geef ze allemaal een geslacht en leg de juiste relaties.
# * Maak een mooi plaatje.
# * Definieer met comprehensies alle relaties die je boven ook gedefinieerd hebt.
#     * Maak ook een plaatje, en check dat het klopt.
# * Zorg dat het er zo netjes en helder uitziet    dat je echt snel en makkelijk kunt checken dat het klopt.
#     * Dit zijn dingen die voor zichzelf spreken: zorg dus ook dat het in jullie opdract zo is.

# %%
import networkx as nx
# %matplotlib inline

# %% [markdown]
# # Uitwerking van opdracht 1
#
# * eerst in Markdown en Latex
# * dan een blok in code

# %% [markdown]
# 1.
#
# $ \forall xy(Vader(x,y) \leftrightarrow R(x,y) \wedge M(x)) $
#
# $ \forall xy(Moeder(x,y) \leftrightarrow R(x,y) \wedge V(x)) $
#
# $ \forall xy(Opa(x,y) \leftrightarrow \exists z(Vader(x,z) \wedge R(z,y))) $
#
# $ \forall xy(Oma(x,y) \leftrightarrow \exists z(Moeder(x,z) \wedge R(z,y))) $
#
# $ \forall xy(Broer(x,y) \leftrightarrow \exists mv(Moeder(m, x) \wedge Moeder(m, y) \wedge Vader(v,x) \wedge Vader(v, y) \wedge M(x)))$
#
# $ \forall xy(Zus(x,y) \leftrightarrow \exists mv(Moeder(m, x) \wedge Moeder(m, y) \wedge Vader(v,x) \wedge Vader(v, y) \wedge V(x)))$
#
# $ \forall xy(Zoon(x,y) \leftrightarrow (R(y,x) \wedge M(x))) $
#
# $ \forall xy(Dochter(x,y) \leftrightarrow (R(y,x) \wedge V(x))) $
#
# $ \forall xy(Oom(x,y) \leftrightarrow \exists z(R(z,y) \wedge Broer(x,z))) $
#
# $ \forall xy(Tante(x,y) \leftrightarrow \exists z(R(z,y) \wedge Zus(x,z))) $
#
# $ \forall xy(Neef(x,y) \leftrightarrow \exists z((Oom(z,y) \vee Tante(z,y)) \wedge Zoon(x,z)) \vee \exists b((Broer(b,y) \vee Zus(b,y)) \wedge Zoon(x,b))) $
#
# $ \forall xy(Nicht(x,y) \leftrightarrow \exists z((Oom(z,y) \vee Tante(z,y)) \wedge Dochter(x,z)) \vee \exists b((Broer(b,y) \vee Zus(b,y)) \wedge Dochter(x,b))) $
#
# $ \forall xy(Overgrootvader(x,y) \leftrightarrow \exists z((Opa(z,y) \vee Oma(z,y)) \wedge Vader(x,z))) $
#
# $ \forall xy(Overgrootmoeder(x,y) \leftrightarrow \exists z((Opa(z,y) \vee Oma(z,y)) \wedge Moeder(x,z))) $
#
# $ \forall xy(Oudoom(x,y) \leftrightarrow \exists z((Opa(z,y) \vee Oma(z,y)) \wedge Broer(x,z))) $
#
# $ \forall xy(Oudtante(x,y) \leftrightarrow \exists z((Opa(z,y) \vee Oma(z,y)) \wedge Zus(x,z))) $
#
# $ \forall xy(Achterneef(x,y) \leftrightarrow \exists z((Oudoom(z,y) \vee Oudtante(z,y)) \wedge Zoon(x,z))) $
#
# $ \forall xy(Achternicht(x,y) \leftrightarrow \exists z((Oudoom(z,y) \vee Oudtante(z,y)) \wedge Dochter(x,z))) $
#
# $ \forall xy(Achterachterneef(x,y) \leftrightarrow \exists z((Achterneef(z,y) \vee Achternicht(z,y)) \wedge Zoon(x,z))) $
#
# $ \forall xy(Achterachternicht(x,y) \leftrightarrow \exists z((Achterneef(z,y) \vee Achternicht(z,y)) \wedge Dochter(x,z))) $
#
# $ \forall xy(Halfbroer(x,y) \leftrightarrow \exists zo(((Moeder(z,x) != Moeder(z,y)) \veebar (Vader(o,x) != Vader(o,y))) \wedge (Zoon(x,z) \vee Zoon(x,o)) \wedge \neg Broer(x,y) \wedge \neg Broer(y,x) \wedge \neg Zus(x,y) \wedge \neg Zus(y,x))) $
#
# $ \forall xy(Halfzus(x,y) \leftrightarrow \exists zo(((Moeder(z,x) != Moeder(z,y)) \veebar (Vader(o,x) != Vader(o,y))) \wedge (Dochter(x,z) \vee Dochter(x,o)) \wedge \neg Broer(x,y) \wedge \neg Broer(y,x) \wedge \neg Zus(x,y) \wedge \neg Zus(y,x))) $
#
#
#
# 2.
# Zwager, echtgenoot en aangetrouwde oom/tante zonder kinderen. Omdat liefdes relaties niet gedefinieerd zijn is het niet mogelijk om een familieband te definieren met bijvoorbeeld een zwager. Er is geen connectie met de zwager en jij behalve dat hij een liefdesrelatie heeft met bijvoorbeeld je zus. Hetzelfde geldt dus ook voor een echtgenoot en een aangetrouwd familielid zonder kinderen. Bijvoorbeeld wanneer een oom en aangetrouwde tante geen kinderen hebben is het niet mogelijk om de relatie tussen jou en de aangetrouwde tante te definieren zonder het gebruik van liefdesrelaties. Hieronder de definitie van een aangetrouwde oom in predicaat logica die dus alleen functioneert wanneer de aangetrouwde oom en tante kinderen hebben.
# $ \forall xy(AangetrouwdeOom(x,y) \leftrightarrow \exists zo((Neef(z,y) \vee Nicht(z,y)) \wedge Vader(x,z) \wedge R(o,z) \wedge \neg (Broer(o,y) \vee Zus(o,y))) \wedge \neg Oom(x,y)) $
#
#
# 3.
# - Niemand heeft twee vaders: $ \neg \exists xyz(R(y,x) \wedge R(z,x) \wedge Vader(y,x) \wedge Vader(z,x)) $
# - Niemand heeft twee moeders: $ \neg \exists xyz(R(y,x) \wedge R(z,x) \wedge Moeder(y,x) \wedge Moeder(z,x)) $
# - Niemand heeft drie ouders: $ \neg \exists xyzp(R(y,x) \wedge R(z,x) \wedge R(p,x)) $
# - Niemand heeft geen ouders: $ \neg \exists xy(\neg R(y,x)) $
# - Niemand heeft geen vader: $ \neg \exists xy(\neg Vader(y,x)) $
# - Niemand heeft geen moeder: $ \neg \exists xy(\neg Moeder(y,x)) $
# - Niemand is broer van zichzelf: $ \neg \exists x(Broer(x,x)) $
# - Niemand is zus van zichzelf: $ \neg \exists x(Zus(x,x)) $
# - Niemand is vader van zichzelf: $ \neg \exists x(Vader(x,x)) $
# - Niemand is Moeder van zichzelf: $ \neg \exists x(Moeder(x,x)) $
# - Niemand is Ouder van zichzelf: $ \neg \exists x(R(x,x)) $
#
#
#
# ![opgave2](https://i.ibb.co/0FDmP6t/c1c78e36-8574-4bab-8a31-96b6886bd557.jpg)

# %%
# conda install -c alubbock pygraphviz
# Als er een error komt is die meldt dat er geen path is voor dot
# Dan open je het command prompt van anaconda en run dan "dot -c"

from networkx.drawing.nx_agraph import graphviz_layout
import matplotlib.pyplot as plt

G= nx.DiGraph()
G.add_nodes_from(range(55))
namen = ['Anna', 'Jan', 'Anne', 'Piet', 'Aaltje', 'Johannes', 'Geertje', 'Gerrit', 'Helena', 'Dirk', 'Mathias', 'Marie', 'Jacob', 'Maria', 
                 'Herman', 'Ben', 'Barry', 'Ed', 'Joey', 'Willem', 'Amber', 'Annete', 'Sylvia', 'Gijs', 'Daan', 'Anna2', 'Nicole', 'Gerrit-Jan', 'Tineke',
                 'Alie', 'Gerrit2', 'Berta', 'Dick', 'Annemari', 'Martijn', 'Merel', 'Chiara', 'Rien', 'Tomas', 'George', 'Maria2', 'Viktor', 'Fenna', 'Bertine',
                 'Marlinde', 'Jarno', 'Joost', 'Bram', 'Marloes', 'Tom', 'Olivia', 'Kaj', 'Corien', 'David', 'Sofie']
F = [0,2,4,6,8,11,13,20,21,22,25,26,28,29,31,33,35,36,40,42,43,44,48,50,52,54]
# Echtgenoot paren
#G.add_edges_from([(0,1), (1,0), (2,3), (3,2), (4,5), (5,4), (6,7), (7,6), (8,9), (9,8), (11, 12), (12,11),
#                 (13,14), (14,13), (17,21), (21, 17), (19, 21), (21, 19), (22,23), (23,22), (26,27), (27,26),
#                 (27,28), (28,27), (29,30), (30,29), (31,32), (32,31), (36,37), (37,36), (40,41), (41,40),
#                 (42,43), (43,42), (44, 45), (45,44), (48,49),(49,48),(52,53), (53,52)])
# Heeft een kind; 0 heeft als kind 8
G.add_edges_from([(0,8), (0,10), (0,11), (1,8), (1,10),(1,11),(2,12),(3,12),(4,13),(5,13),(6,14),(7,14),
                 (8,15),(8,16),(9,15),(9,16),(11,21),(11,22),(11,26),(12,21),(12,22),(12,26), 
                 (13,27),(13,30),(13,31),(13,33),(14,27),(14,30),(14,31),(14,33),(17,18),(19,20),(21,18),(21,20),
                 (22,24),(22,25),(23,24),(23,25),(26,34),(26,35),(27,34),(27,35),(27,37),(27,40),(27,43),
                 (28,37),(28,40),(28,43),(29,44),(29,48),(29,52),(30,44),(30,48),(30,52),
                 (36,38),(36,39),(37,38),(37,39),(44,46),(44,47),(45,46),(45,47),(48,50),(48,51),(49,50),(49,51),
                 (52,54),(53,54)])

kleuren= []
for node in G.nodes:
    if node in F:
        kleuren.append('pink')
        G.nodes[node]['geslacht'] = 'F'
    else:
        kleuren.append('blue')
        G.nodes[node]['geslacht'] = 'M'
    G = nx.relabel_nodes(G, {node: namen[node]})

plt.figure(3,figsize=(8,8)) 
# Zonder installatie van pygraphviz
nx.draw(G, node_color=kleuren, with_labels=True)
# Met installatie van pygraphviz
# pos =graphviz_layout(G, prog='dot')
# nx.draw(G, pos, node_color=kleuren, with_labels=True, arrows=True)

def M(x, network=G):
  if network.nodes[x]['geslacht'] == "M":
    return True
  else:
    return False
def V(x, network=G):
  if network.nodes[x]['geslacht'] == "F":
    return True
  else:
    return False
def R(x,y,network=G):
  return network.has_edge(x,y)

# %%
#Comprehensies
#Vader(x,y): x is de vader van y, Moeder(x,y): x is de moeder van y, enz
F=G
Vader= {(x,y) for x in F for y in F if R(x,y,F) & M(x,F)}
print("Vader:", len(Vader), Vader)

Moeder= {(x,y) for x in F for y in F if R(x,y,F) & V(x,F)}
print("Moeder:", len(Moeder), Moeder)

Opa= {(x,y) for x in F for y in F
      if {z for z in F if (x,z) in Vader and R(z,y,F)}}
print("Opa:", len(Opa), Opa)

Oma= {(x,y) for x in F for y in F
      if {z for z in F if (x,z) in Moeder and R(z,y,F)}}
print("Oma:", len(Oma), Oma)

Broer= {(x,y) for x in F for y in F
      if {(m,v) for m in F for v in F if ((m,x) in Moeder and (m,y) in Moeder) and ((v,x) in Vader and (v,y) in Vader) and M(x)}  and x!=y }
print("Broer:", len(Broer), Broer)

Zus= {(x,y) for x in F for y in F
      if {(m,v) for m in F for v in F if ((m,x) in Moeder and (m,y) in Moeder) and ((v,x) in Vader and (v,y) in Vader) and V(x)} and x!=y}
print("Zus:", len(Zus), Zus)

Zoon= {(x,y) for x in F for y in F if R(y,x,F) & M(x,F)}
print("Zoon:", len(Zoon), Zoon)

Dochter= {(x,y) for x in F for y in F if R(y,x,F) & V(x,F)}
print("Dochter:", len(Dochter), Dochter)

Oom= {(x,y) for x in F for y in F
      if {z for z in F if R(z,y,F) and (x,z) in Broer}}
print("Oom:", len(Oom), Oom)

Tante= {(x,y) for x in F for y in F
      if {z for z in F if R(z,y,F) and (x,z) in Zus}}
print("Tante:", len(Tante), Tante)

Neef= {(x,y) for x in F for y in F
      if {z for z in F if ((z,y) in Oom or (z,y) in Tante) and (x,z) in Zoon} or {b for b in F if ((b,y) in Broer or (b,y) in Zus) and (x,b) in Zoon}}
print("Neef:", len(Neef), Neef)

Nicht= {(x,y) for x in F for y in F
      if {z for z in F if ((z,y) in Oom or (z,y) in Tante) and (x,z) in Dochter} or {b for b in F if ((b,y) in Broer or (b,y) in Zus) and (x,b) in Dochter}}
print("Nicht:", len(Nicht), Nicht)

Overgrootvader= {(x,y) for x in F for y in F
      if {z for z in F if ((z,y) in Opa or (z,y) in Oma) and (x,z) in Vader}}
print("Overgrootvader:", len(Overgrootvader), Overgrootvader)

Overgrootmoeder= {(x,y) for x in F for y in F
      if {z for z in F if ((z,y) in Opa or (z,y) in Oma) and (x,z) in Moeder}}
print("Overgrootmoeder:", len(Overgrootmoeder), Overgrootmoeder)

Oudoom = {(x,y) for x in F for y in F
      if {z for z in F if ((z,y) in Opa or (z,y) in Oma) and (x,z) in Broer}}
print("Oudoom:", len(Oudoom), Oudoom)

Oudtante = {(x,y) for x in F for y in F
      if {z for z in F if ((z,y) in Opa or (z,y) in Oma) and (x,z) in Zus}}
print("Oudtante:", len(Oudtante), Oudtante)

Achterneef= {(x,y) for x in F for y in F
      if {z for z in F if ((z,y) in Oudoom or (z,y) in Oudtante) and (x,z) in Zoon}}
print("Achterneef:", len(Achterneef), Achterneef)

Achternicht= {(x,y) for x in F for y in F
      if {z for z in F if ((z,y) in Oudoom or (z,y) in Oudtante) and (x,z) in Dochter}}
print("Achternicht:", len(Achternicht), Achternicht)

Achterachterneef= {(x,y) for x in F for y in F
      if {z for z in F if ((z,y) in Achterneef or (z,y) in Achternicht) and (x,z) in Zoon}}
print("Achterachterneef:", len(Achterachterneef), Achterachterneef)

Achterachternicht= {(x,y) for x in F for y in F
      if {z for z in F if ((z,y) in Achterneef or (z,y) in Achternicht) and (x,z) in Dochter}}
print("Achterachternicht:", len(Achterachternicht), Achterachternicht)

Halfbroer= {(x,y) for x in F for y in F
      if {(z,z1) for z in F for z1 in F if (bool((z,x) in Moeder != (z,y) in Moeder) ^ bool((z1,x) in Vader != (z1,y) in Vader)) and ((x,z) in Zoon or (x,z1) in Zoon) and x != y and ((x,y) and (y,x)) not in Broer and ((x,y) and (y,x)) not in Zus }}
print("Halfbroer:", len(Halfbroer), Halfbroer)

Halfzus= {(x,y) for x in F for y in F
      if {(z,z1) for z in F for z1 in F if (bool((z,x) in Moeder != (z,y) in Moeder) ^ bool((z1,x) in Vader != (z1,y) in Vader)) and ((x,z) in Dochter or (x,z1) in Dochter) and x != y and ((x,y) and (y,x)) not in Broer and ((x,y) and (y,x)) not in Zus }}
print("Halfzus:", len(Halfzus), Halfzus)
# Out:
# Vader: 34 {('Tom', 'Kaj'), ('Herman', 'Berta'), ('Dirk', 'Barry'), ('Willem', 'Amber'), ('Gerrit-Jan', 'Bertine'), ('Dirk', 'Ben'), ('Jacob', 'Annete'), ('Gerrit2', 'Marloes'), ('Tom', 'Olivia'), ('Jarno', 'Joost'), ('Herman', 'Gerrit-Jan'), ('Gerrit2', 'Marlinde'), ('Gerrit-Jan', 'Rien'), ('Jan', 'Helena'), ('David', 'Sofie'), ('Rien', 'George'), ('Herman', 'Gerrit2'), ('Gerrit-Jan', 'Martijn'), ('Gerrit2', 'Corien'), ('Ed', 'Joey'), ('Gerrit', 'Herman'), ('Piet', 'Jacob'), ('Gijs', 'Daan'), ('Gerrit-Jan', 'Maria2'), ('Jacob', 'Nicole'), ('Johannes', 'Maria'), ('Herman', 'Annemari'), ('Jan', 'Mathias'), ('Gerrit-Jan', 'Merel'), ('Rien', 'Tomas'), ('Jacob', 'Sylvia'), ('Jarno', 'Bram'), ('Gijs', 'Anna2'), ('Jan', 'Marie')}
# ...

# %% [markdown]
# # 2 Definieer LHBTQI+
#
# * OK, ga er maar aan staan. Linda probeert het op <https://www.linda.nl/nieuws/we-leggen-het-gewoon-uit-waar-staat-lhbtqi-voor/>.
# * Nu is het jullie beurt.
# * Dus neem wat primitieven, maar zo min mogelijk,
#     * Man, Vrouw, en allicht nog iets, plus logische relaties daartussen
#     * een binaire relatie $R$ die "liefdes-relaties" aangeeft...
#         * Jij geeft heel exact aan wat $R(x,y)$ voor jullie betekent
#     * misschien nog 1 of 2 andere primitieven
#         * Geef heel exact aan wat ze betekenen
#
# ### Let op!
#
# * Vergelijk deze 3 (echt niet equivalente) definities:
#     * Je bent een hetero als je van iemand houdt van het andere geslacht
#     * ... als je alleen maar van mensen houdt van het andere geslacht
#     * ... als je van iemand houdt van het andere geslacht **en** als je alleen maar van mensen houdt van het andere geslacht
#     * eeh, *het* andere geslacht..., is er maar 1 dan?
# * Je merkt het, je moet heel precies zijn!
# * Deze opdracht is alleen goed te doen, als jullie elkaar steeds controleren en scherp houden, en opjutten om precies te zijn of worden of blijven.
# * Maak ook steeds heldere voorbeelden/modellen, en kijk wat je definities doen op die modellen.
#
# ## Jullie opdracht
#
# * Maak net als boven een theorie voor je primitieven, en definieer alle letters (plus wat er onder de + valt) in termen van je primitieven
# * Als het echt niet lukt of kan, zal je dat echt helder moeten motiveren.
# * Maak een networkx model met van elke LHBTQI+ letter minstens 1 knoop die zo is volgens jouw definitie.
# * Geef exact aan, of mensen meerdere letters tegelijk kunnen zijn,
#     * Is iedereen nou 1 van deze letters, of zijn er ook nog andere categorieen? Welke dan? Kan je die ook definieren?

# %% [markdown]
# # Uitwerking van opdracht 2
#
# * eerst in Markdown en Latex
# * dan een blok in code

# %% [markdown]
# ```
# # Dit is opgemaakt als code
# ```
#
# Relaties: Liefdesrelatie
#
# Geslachten: Man, Vrouw, Intersex en Non-binair
#
# Sexualiteiten: Homo, Lesbisch, Biseksueel, Queer en Aseksueel
#
# We gaan er bij deze definities van uit dat de personen in het netwerk hun sexualiteit al geuit hebben in de vorm van een relatie.
#
# Non-binair: Iemand die zich niet identificeert als man of vrouw.
#
# $ \forall x(NonBinair(x) \leftrightarrow \neg (M(x) \lor V(x))) $
#
# Interseks: Iemand met geslachtskenmerken van zowel man als vrouw.
#
# $ \forall x(Interseksueel(x) \leftrightarrow (M(x) \land V(x))) $
#
# Homo: Een man die alleen op andere mannen valt.
#
# $ \forall xy(Homo(x) \leftrightarrow M(x) \land R(x,y) \land M(y)) $
#
# Lesbienne: Een vrouw die alleen op vrouwen valt.
#
# $ \forall xy(Lesbienne(x) \leftrightarrow V(x) \land R(x,y) \land V(y)) $
#
# Biseksueel: Iemand die op zowel mannen als vrouwen valt.
#
# $ \forall x(Biseksueel(x) \leftrightarrow \exists yz(R(x, y) \land M(y) \land R(x,z) \land V(z))) $
#
# Asexueel: Iemand die op niemand valt.
#
# $ \forall xy(Aseksueel(x) \leftrightarrow \neg  R(x,y)) $
#
# Queer: Iemand die niet alleen hetero relaties heeft gehad.
#
# $ \forall x(Queer(x) \leftrightarrow \neg \exists y(R(x,y) \wedge (M(x)) \wedge V(y)) \vee (M(y) \wedge V(x)))  $
#
# Bij een Transgender (T) persoon veranderd iemand van Man naar Vrouw. Dit zien wij als een verse start, en wordt voor deze persoon x een nieuwe node yaangemaakt het het juiste geslacht. Als naar deze persoon verwezen wordt, wordt dit gedaan als (x,y). Deze keuze is gemaakt zodat de relaties die de persoon voor de transitie had niet met de persoon mee veranderen.
#
# Het is mogelijk om onder meer dan een categorie te vallen. Zo kan iemand bijvoorbeeld onder zowel Interseksueel als Biseksueel vallen.
# - $ \forall x(InterseksueleBiseksuele(x) \leftrightarrow (M(x) \land V(x)) \land \exists yz(R(x, y) \land M(y) \land R(x,z) \land V(z))) $
# - $ \forall x(NonBinaireBiseksuele(x) \leftrightarrow \neg (M(x) \lor V(x)) \land \exists yz(R(x, y) \land M(y) \land R(x,z) \land V(z))) $
# - $ \forall x(InterseksueleAseksuele(x) \leftrightarrow (M(x) \land V(x)) \land \neg  R(x,y)) $
# - $ \forall x(NonBinaireAseksuele(x) \leftrightarrow \neg (M(x) \lor V(x)) \land \neg  R(x,y)) $

# %%
# YOUR CODE HERE
# Voorbeeld om je op weg te helpen

H= nx.Graph()
H.add_nodes_from(range(0,12))
H.add_edges_from({(0,1),(1,2),(0,5),(9,7),(4,9),(3,4),(5,9),(4,8),(8,10),(3,10)})
M= {0,5,7,8,9,10,11}
V = {1,2,4,8,11}
# Nu even de attributen M en V goed zetten
kleuren= []
for node in H.nodes:
    if node in V and node in M:
      kleuren.append("purple")
      H.nodes[node]['geslacht'] = 'F&M'
    elif node in V:
        kleuren.append('pink')
        H.nodes[node]['geslacht'] = 'F'
    elif node in M:
        kleuren.append('blue')
        H.nodes[node]['geslacht'] = 'M'
    else:
      kleuren.append('green')
      H.nodes[node]['geslacht'] = 'NB'
nx.draw_networkx(H, node_color=kleuren)
# wat handige afkortingen om de comprehensies zo veel mogelijk op je formules te laten lijken
def M(x, network=H):
  if network.nodes[x]['geslacht'] == "M":
    return True
  else:
    return False
def V(x, network=H):
  if network.nodes[x]['geslacht'] == "F":
    return True
  else:
    return False
def R(x,y,network=H):
  return network.has_edge(x,y)

# %% [markdown]
# Lesbienne: {2}
# Homosexueel: {5}
# Bisexueel: {0,1,3,8,9}
# Transgender: {(7,4)}
# Queer: {0,1,3,6,8,9}
# Asexueel: {6,8}
# Intersex: {8}
# Niet-Binair: {3,6}
# InterseksueleBiseksuele: {8}
# Non-BinaireBiseksuele: {3}
# InterseksueleAseksuele: {11}
# Non-BinaireAseksuele: {6}
